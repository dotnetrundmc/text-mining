# %%
import pandas as pd
import os
import requests
import gzip #Combine test and train files
from xml.etree import ElementTree as ET
from collections import defaultdict

# %%
os.getcwd()
# Out:
# 'C:\\Users\\devsa\\Documents\\Pubtator'

# %%
# Combining Gene-Disease test & train data files
# this is from: https://figshare.com/articles/dataset/CoCoScore_Supplementary_Data_v1_0/7198280/1
file1_path = 'dataset_9606_-26_test.tsv.gz'
file2_path = 'dataset_9606_-26_train.tsv.gz'
output_file_path = 'Gene_Disease.tsv.gz'

# Function to combine two TSV files
def combine_tsv_files(file1_path, file2_path, output_file_path):
    with gzip.open(file1_path, 'rb') as file1:
        data1 = file1.read()
    
    with gzip.open(file2_path, 'rb') as file2:
        data2 = file2.read()
    
    combined_data = data1 + data2

    with gzip.open(output_file_path, 'wb') as output_file:
        output_file.write(combined_data)

# %%
combine_tsv_files(file1_path, file2_path, output_file_path)
print("Files combined successfully and saved to", output_file_path)
# Out:
# Files combined successfully and saved to Gene_Disease.tsv.gz

# %%
# Specify the path to your TSV file
file_path = 'Gene_Disease.tsv.gz'

# Specify column names (replace with your actual column names)
column_names = ['PMID', 'Paragraph No', 'Sentence No', 'Diseas ID', 'Gene ID', 'Text', 'Association_label', 'H']

# Read the tab-separated TSV file into a DataFrame
df = pd.read_csv(file_path, sep='\t', names=column_names)

df['PMID'] = df['PMID'].astype(str)

# %%
# Display the first few rows of the DataFrame
print(df.head())
# Out:
#     PMID  Paragraph No  Sentence No   Diseas ID          Gene ID  \
# 0   1401             2            1    DOID:684  ENSP00000448059
# 1  11906             2            1   DOID:2752  ENSP00000305692
# 2  15739             2            1  DOID:14749  ENSP00000274813
# 3  22474             2            4    DOID:684  ENSP00000357066
# 4  36611             2            3  DOID:12800  ENSP00000264914
#
#                                                 Text  Association_label    H
# 0  Stationary-phase, minimal deviation UNKDISEASE...                  0   89
# 1  We describe an improved method for detecting d...                  1    2
# 2  We report a method for rapid prenatal detectio...                  1   52
# 3  The UNKGENE (UNKGENE), UNKGENE (UNKGENE), and ...                  0  131
# 4  Deficiency of UNKGENE (ARS(B)) is associated w...                  1   75

# %%
len(df)
# Out:
# 587208

# %%
# Changelog (after Micheal's code) 

# 1.  I merged test and train into one dataset
# 2.  Checked if we can give more that 100 through get method, I tried with 1000 worked for me. 
#     But It takes 3 mins for every 100 request. Did not time how long it took for 1000 - But definitely less than 30 mins.
# 3.  Created a dictionary to store output (#Key: Concept_name, Value: Pubmed_id's) - 
#     created a condition for the PubMed ID to be added to the list of values if it's not already present in the list for 
#     a given concept name.
# 4.  Encapsulated the code to "fetch_pubmed_concepts" function to be used recursively. 
#     Takes your DataFrame "df" and an optional parameter max_pmid_count to specify the maximum number of PMIDs you want to 
#     process. It returns the dictionary as the result.
 
#  - Siva

# %%
#Continued... 31/08/2023

# %%
from tqdm import tqdm 

def fetch_pubmed_concepts_df(df, max_pmid_count):
    # Feed DataFrame with a column 'PMID'
    
    pmid_first_n = df['PMID'][:max_pmid_count]
    querylist = pmid_first_n.tolist()
    pubtator_api_url = "https://www.ncbi.nlm.nih.gov/research/pubtator-api/publications/export/biocxml"



    # Query the list as per API states
    for pmid in querylist:
        url = f"{pubtator_api_url}?pmids={pmid}&concepts=gene"
        response = requests.get(url)

        print(f"Submitting request for PMID {pmid}: {url}")

        
        if response.status_code == 200:
            content = response.content
            root = ET.fromstring(content)
            for passage in root.iter('passage'):
                for annotation in passage.iter('annotation'):
                    
                    gene_id = annotation.find("infon[@key='identifier']").text
                    
                    #Gene_name
                    concept_name = annotation.find("text").text.lower()
                    concept_type = annotation.find("infon[@key='type']").text

                    #Couunt occurances per pmid
                    concept_count[(concept_name, pmid)] += 1

                    if concept_count[(concept_name, pmid)] == 1:
                        concept_data.append({
                            'gene_id': gene_id,
                            'concept_name': concept_name,
                            'pubmed_id': pmid,
                            'count': concept_count[(concept_name, pmid)]
                        })
                    else:
                        concept_data[-1]['count'] = concept_count[(concept_name, pmid)]
        else:
            print(f"Request for PMID {pmid} failed with status code {response.status_code}")

    # Create a DataFrame from the concept data
    concept_df = pd.DataFrame(concept_data)

    return concept_df

# %%
from tqdm import tqdm #Progress_bar shows status of fetch request from api

def fetch_pubmed_concepts_df(df, max_pmid_count):
     
    # Feed DataFrame with a column 'PMID'    
    pmid_first_n = df['PMID'][:max_pmid_count]
    querylist = pmid_first_n.tolist()
    pubtator_api_url = "https://www.ncbi.nlm.nih.gov/research/pubtator-api/publications/export/biocxml"
    
    # List to store concept data as dictionaries
    concept_data = []  
    # To count concept_id occurrences per pubmed_id
    concept_count = defaultdict(int)  

    # Initialize tqdm for the progress bar
    with tqdm(total=len(querylist)) as pbar:
        for pmid in querylist:
            url = f"{pubtator_api_url}?pmids={pmid}&concepts=gene"
            response = requests.get(url)

            if response.status_code == 200:
                content = response.content
                root = ET.fromstring(content)
                for passage in root.iter('passage'):
                    for annotation in passage.iter('annotation'):
                        
                        #NCBI GENE ID (Ref: https://www.ncbi.nlm.nih.gov/gene/)
                        gene_id = annotation.find("infon[@key='identifier']").text 
                        #Gene_name
                        concept_name = annotation.find("text").text.lower()
                        concept_type = annotation.find("infon[@key='type']").text

                        concept_count[(concept_name, pmid)] += 1

                        if concept_count[(concept_name, pmid)] == 1:
                            concept_data.append({
                                'gene_id': gene_id,
                                'concept_name': concept_name,
                                'pubmed_id': pmid,
                                'count': concept_count[(concept_name, pmid)]
                            })
                        else:
                            concept_data[-1]['count'] = concept_count[(concept_name, pmid)]
            else:
                print(f"Request for PMID {pmid} failed with status code {response.status_code}")

            pbar.update(1)  # Update the progress bar

    # Create a DataFrame from the fetched data
    concept_df = pd.DataFrame(concept_data)

    return concept_df

# %%
# Usage
# df is the DataFrame, and you can specify the max number of PMIDs you want to process
result_df = fetch_pubmed_concepts_df(df, max_pmid_count=1000)

# Now 'result_df' contains the concept data in a DataFrame with columns 'gene_id', 'concept_name', 'pubmed_id', and 'count'
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [21:40<00:00,  1.30s/it]

# %%
print(result_df)
# Out:
#         gene_id                        concept_name pubmed_id  count
# 0         24616           phenylalanine hydroxylase      1401      4
# 1          6476                   alpha-glucosidase     11906      1
# 2          3630                             insulin     22474      1
# 3           410                     arylsulfatase a     36611      1
# 4           410                              ars(a)     36611      1
# ...         ...                                 ...       ...    ...
# 1329       4790  retinoblastoma gene product (p105)   1673033      1
# 1330       7984                                 p60   1673033      3
# 1331  7984;4790                           p60/p105/   1673033      6
# 1332       7157                                 p53   1673792      8
# 1333        914                                 cd2   1673843     18
#
# [1334 rows x 4 columns]

# %%
csv_file_path = 'result_df.csv'
result_df.to_csv(csv_file_path, index=False)

print(f'Results saved to {csv_file_path}')
# Out:
# Results saved to result_df.csv

# %%
# Find rows with semicolon in 'gene_id'
rows_with_semicolon = result_df[result_df['gene_id'].str.contains(';')]

# Display the rows with semicolon in 'gene_id'
rows_with_semicolon
# Out:
#                                  gene_id                         concept_name  \
# 66                             3073;3074                          hex a and b
# 88                               718;720                               c3, c4
# 112                            3073;3074                   hex a- and hex b-)
# 115                            3105;3106                      hla-a, b, and d
# 147                              718;629          c3, c3, c4, c3-proactivator
# 187                              720;718                               c4, c3
# 198                              718;720                               c3, c4
# 316                           4855;18132                                notch
# 429                            3479;3481                        igf-i and -ii
# 749                            3040;3043                alpha and beta globin
# 768                       3105;3106;3107             hla-a, b, c) of class ii
# 784   3106;3107;3133;3105;3136;3135;3134  hla-b, -c, -e, (-a, -h, -g), and -f
# 802                            3117;3119                     hla-dqa and -dqb
# 931                  3558;3562;3565;3569            interleukin-2, -3, -4, -6
# 1096                      3105;3106;3107                          hla-a, b, c
# 1212                         15967;15969             ifn-alpha 4 and -alpha 6
# 1331                           7984;4790                            p60/p105/
#
#      pubmed_id  count
# 66      230195      1
# 88      334183      1
# 112     545716      1
# 115     571573      1
# 147     919557      1
# 187    1185743      1
# 198    1245600      1
# 316    1312643      3
# 429    1339481      2
# 749    1415186      1
# 768    1421624      1
# 784    1427838      1
# 802    1429035      1
# 931    1462123      2
# 1096   1550412      1
# 1212   1614874      3
# 1331   1673033      6

# %%
import csv

data = {}
with open('result_df.csv', 'r') as f:
    reader = csv.reader(f)
    next(reader)
    
    for row in reader:
        concept_name = row[1]
        pubmed_id = row[2]
        
        if concept_name not in data:
            data[concept_name] = []
            
        data[concept_name].append(pubmed_id)

# %%
print(data)
# Out:
# {'phenylalanine hydroxylase': ['1401', '489556'], 'alpha-glucosidase': ['11906'], 'insulin': ['22474', '182362', '323439', '353918', '739270', '842341', '1105371', '1110865', '1144451', '1147652', '1285360', '1307748', '1333648', '1339481', '1347765', '1377520', '1442714', '1459319', '1550404', '1550446', '1592883', '1641148'], 'arylsulfatase a': ['36611'], 'ars(a)': ['36611'], 'ars(b)': ['36611'], 'mitochondrial aconitase': ['36611'], 'alpha-1': ['48211'], 'alpha-2': ['48211', '71842'], 'antithrombin': ['48766', '578072', '926106'], 'iga': ['52952', '651380', '926106', '1469522'], 'alpha-1-antitrypsin': ['58261', '314560', '1441675', '1542282'], 'alpha1-antitrypsin': ['58261'], 'acid beta-galactosidase': ['62026'], 'albumin': ['65455', '489556', '1498561', '1542282', '1577950'], 'alpha-2-macroglobulin': ['71842'], 'transferrin': ['71842', '1222826', '1498561'], 'haptoglobin': ['71842', '1222826'], 'hla-a': ['77056', '480486', '677553', '1341477', '1349923', '1427838'], 'nerve-growth-factor': ['83481'], 'nerve-growth factor': ['83481'], 'beta-galactosidase': ['83795', '98248', '174379', '804170'], 'thyroglobulin': ['93993', '95586', '181398', '234498', '306159', '307474', '316371', '344076', '384139', '401730', '446310', '564103', '576614', '577211', '580305', '580417', '583090', '583403', '682610', '699062', '1036742', '1201740', '1283174', '1284333', '1373164', '1378862', '1391597', '1418298', '1472632', '1493370', '1530862', '1570743', '1643752', '1669847'], 'ga2': ['99746'], 'saa': ['103558'], 'complement c3': ['114636', '1008062'], 'erythropoietin': ['119408'], 'androgen receptor': ['168054', '1307250', '1347772', '1356901', '1461383', '1472458', '1480178', '1513460', '1624772'], 'tfm': ['172903', '194654', '939201', '1248804', '1624772', '1632191'], 'alpha- and beta-glucosidase': ['172998'], 'alpha- and beta-galactosidase': ['172998'], 'beta mannosidase': ['172998'], 'galactokinase': ['173184', '173185', '194478', '204112', '1438294'], 'galactose-1-phosphate uridylyltransferase': ['173184', '173185'], 'galk': ['173184', '173185', '194478'], 'galactose-1-phosphate uridylyl-transferase': ['173184'], 'galt': ['173184', '173185'], 'serum albumin': ['177236', '545716', '576614'], 'proinsulin': ['182362'], 'nerve growth factor': ['188519', '1036092', '1116148', '1339481', '1527053', '1647645'], 'ngf': ['188519', '1036092', '1527053'], 'glucose-6-phosphatase': ['192899', '205362'], 'g-6-pase': ['192899'], 'galactose-1-phosphate uridyltransferase': ['204112'], 'gal-1': ['204112'], 'gal-1-put': ['204112'], 'pyruvate carboxylase': ['205362'], 'pc': ['205362'], 'phosphoenolpyruvate carboxykinase': ['205362'], 'pepck': ['205362'], 'g6pase': ['205362'], 'hex a and b': ['230195'], 'hex': ['230195'], 'beta hexosaminidase': ['240271'], 'hex a': ['240271', '545716', '808963', '1424119'], 'hex b': ['240271', '808963'], 'ck': ['265697'], 'delta-aminolevulinic acid dehydratase': ['299239'], 'd-ala-d': ['299239'], 'porphobilinogen deaminase': ['299239'], 'pbg-d': ['299239'], 'ferrochelatase': ['299239', '484541'], 'fch': ['299239'], 'c1 esterase': ['313695'], 'viiivwf': ['316435'], 'fab': ['316435'], 'glucagon': ['323439', '842341', '1105371', '1339481', '1592883', '1641148'], 'c3, c4': ['334183', '1245600'], 'c3, c4, factor b': ['334183'], 'migration inhibition factor': ['401730'], 'mif': ['401730'], 'cnf': ['408143', '616039', '620450', '1451338'], 'c3a': ['414916', '1444625'], 'antithrombin iii': ['435403', '1202173', '1530443', '1542282', '1569192', '1649042', '1662049'], 'at iii': ['435403', '1649042'], 'acid phosphatase': ['471190'], 'hla-b': ['480486', '677553', '1341477', '1356945', '1359669', '1362479', '1672123'], 'catalase': ['481442'], 'sod': ['481442'], 'sta': ['545716'], 'hex a-)': ['545716'], 'hex a- and hex b-)': ['545716'], 'hla-a, b, and d': ['571573'], 'coagulation factor x': ['573131'], 'thrombin': ['573131', '1569192'], 'tg': ['577211', '580305', '583403'], 'a-10': ['639065'], 'lcat': ['650257'], 'c3-proactivator': ['675 ...

# %%
#Invert the dictionary to map pubmed ids to concepts

pubmed_to_concepts = {}
for concept, pmids in data.items():
    for pmid in pmids:
        if pmid not in pubmed_to_concepts:
             pubmed_to_concepts[pmid] = []
        pubmed_to_concepts[pmid].append(concept)

# %%
pubmed_to_concepts
# Out:
# {'1401': ['phenylalanine hydroxylase'],
#  '489556': ['phenylalanine hydroxylase', 'albumin'],
#  '11906': ['alpha-glucosidase'],
#  '22474': ['insulin'],
#  '182362': ['insulin', 'proinsulin'],
#  '323439': ['insulin', 'glucagon'],
#  '353918': ['insulin'],
#  '739270': ['insulin'],
#  '842341': ['insulin', 'glucagon'],
#  '1105371': ['insulin', 'glucagon', 'growth hormone', 'gh'],
#  '1110865': ['insulin'],
#  '1144451': ['insulin'],
#  '1147652': ['insulin'],
#  '1285360': ['insulin',
#   'gastrin-releasing peptide',
#   'grp',
#   'vasopressin',
#   'avp',
#   'neuropeptide y',
#   'npy',
#   'corticotropin releasing hormone',
#   'crh',
#   'acth'],
#  '1307748': ['insulin'],
#  '1333648': ['insulin', 'adrenocorticotropic hormone', 'prolactin'],
#  '1339481': ['insulin',
#   'nerve growth factor',
#   'glucagon',
#   'igf-ii',
#   'igf-i',
#   'insulin-like growth factor i',
#   'rbp-1',
#   'rbp-2',
#   'p107',
#   'beta-endorphin',
#   'igf-i and -ii'],
#  '1347765': ['insulin', 'hla-drb1', 'dqa1', 'dqb1', 'drb1'],
#  '1377520': ['insulin', 'igf-1', 'igf-2'],
#  '1442714': ['insulin', 'dqb1', 'leukocyte antigen (hla) dqa1'],
#  '1459319': ['insulin', 'hla-dqb1', 'hla', 'dqa1', 'dqb1'],
#  '1550404': ['insulin', 'il-6', 'il-1', 'interleukin 6'],
#  '1550446': ['insulin', 'dr3', 'dr4'],
#  '1592883': ['insulin', 'glucagon', 'ttr', 'transthyretin'],
#  '1641148': ['insulin', 'glucagon'],
#  '36611': ['arylsulfatase a', 'ars(a)', 'ars(b)', 'mitochondrial aconitase'],
#  '48211': ['alpha-1', 'alpha-2'],
#  '71842': ['alpha-2', 'alpha-2-macroglobulin', 'transferrin', 'haptoglobin'],
#  '48766': ['antithrombin'],
#  '578072': ['antithrombin'],
#  '926106': ['antithrombin', 'iga'],
#  '52952': ['iga'],
#  '651380': ['iga'],
#  '1469522': ['iga',
#   'cd4',
#   'cd8',
#   'il-2r',
#   'interleukin 2 receptor',
#   'iga-aga'],
#  '58261': ['alpha-1-antitrypsin', 'alpha1-antitrypsin'],
#  '314560': ['alpha-1-antitrypsin'],
#  '1441675': ['alpha-1-antitrypsin', 'alpha 1-antitrypsin', 'alpha 1-at'],
#  '1542282': ['alpha-1-antitrypsin',
#   'albumin',
#   'antithrombin iii',
#   'fibrinogen',
#   'c-reactive protein',
#   'crp',
#   'a1at',
#   'viii'],
#  '62026': ['acid beta-galactosidase'],
#  '65455': ['albumin'],
#  '1498561': ['albumin', 'transferrin'],
#  '1577950': ['albumin', 'tnf-alpha', 'tumor necrosis factor-alpha'],
#  '1222826': ['transferrin', 'haptoglobin', 'hemopexin', 'ceruloplasmin'],
#  '77056': ['hla-a'],
#  '480486': ['hla-a', 'hla-b'],
#  '677553': ['hla-a', 'hla-b'],
#  '1341477': ['hla-a', 'hla-b'],
#  '1349923': ['hla-a', 'psti'],
#  '1427838': ['hla-a', 'hfe', 'hla-b, -c, -e, (-a, -h, -g), and -f'],
#  '83481': ['nerve-growth-factor', 'nerve-growth factor'],
#  '83795': ['beta-galactosidase'],
#  '98248': ['beta-galactosidase'],
#  '174379': ['beta-galactosidase'],
#  '804170': ['beta-galactosidase', 'neuraminidase'],
#  '93993': ['thyroglobulin'],
#  '95586': ['thyroglobulin'],
#  '181398': ['thyroglobulin'],
#  '234498': ['thyroglobulin'],
#  '306159': ['thyroglobulin'],
#  '307474': ['thyroglobulin'],
#  '316371': ['thyroglobulin'],
#  '344076': ['thyroglobulin'],
#  '384139': ['thyroglobulin'],
#  '401730': ['thyroglobulin', 'migration inhibition factor', 'mif'],
#  '446310': ['thyroglobulin'],
#  '564103': ['thyroglobulin'],
#  '576614': ['thyroglobulin', 'serum albumin'],
#  '577211': ['thyroglobulin', 'tg'],
#  '580305': ['thyroglobulin', 'tg'],
#  '580417': ['thyroglobulin'],
#  '583090': ['thyroglobulin'],
#  '583403': ['thyroglobulin', 'tg'],
#  '682610': ['thyroglobulin'],
#  '699062': ['thyroglobulin'],
#  '1036742': ['thyroglobulin'],
#  '1201740': ['thyroglobulin'],
#  '1283174': ['thyroglobulin'],
#  '1284333': ['thyroglobulin', 'tpo', 'tsh receptor'],
#  '1373164': ['thyroglobulin'],
#  '1378862': ['thyroglobulin'],
#  '1391597': ['thyroglobulin'],
#  '1418298': ['thyroglobulin'],
#  '1472632': ['thyroglobulin'],
#  '1493370': ['thyroglobulin'],
#  '1530862': ['thyroglobulin'],
#  '1570743': ['thyroglobulin'],
#  '1643752': ['thyroglobulin', 'cd4'],
#  '1669847': ['thyroglobulin'],
#  '99746': ['ga2'],
#  '103558': ['saa'],
#  '114636': ['complement c3'],
#  '1008062': ['complement c3'],
#  '119408': ['erythropoietin'],
#  '168054': ['androgen receptor'],
#  '1307250': ['androgen receptor'],
#  '1347772': ['androgen receptor', 'ar'],
#  '1356901': ['androgen receptor'],
#  '1461383': ['androgen receptor', 'sbma'],
#  '1472458': ['androgen receptor', 'ar', 'psti'],
#  '1480178': ['androgen receptor', 'ar'],
#  '1513460': ['androgen receptor', 'ar', 'sbma'],
#  '1624772': ['androgen receptor', 'tfm', 'ta', 'tabby'],
#  '172903': ['tfm'],
#  '194654': ['tfm'],
#  '939201': ['tfm'],
#  '1248804': ['tfm'],
#  '1632191': ['tfm'],
#  '172998': ['alpha- and beta-glucosidase',
#   'alpha- and beta-galactosidase',
#   'beta mannosidase'],
#  '173184': ['galactokinase',
#   'galactose-1-phosphate uridylyltransferase',
#   'galk',
#   'galactose-1-phosphate uridylyl-transferase',
#   'galt'],
#  '173185': ['galactokinase',
#   'galactose-1-phosphate uridylyltransferase',
#   'galk',
#   'galt'],
#  '194478': ['galactokinase', 'galk'],
#  '204112': ['galactokinase',
#   'galactose-1-phosphate uridyltransferase',
#   'gal-1',
#   'gal-1-put'],
#  '1438294': ['galactokinase', 'gk2', 'gal1', 'gk1'],
#  '177236': ['serum albumin'],
#  '545716': ['serum albumin', 'hex a', 'sta', 'hex a-)', 'hex a- and hex b-)'],
#  '188519': ['nerve growth factor', 'ngf'],
#  '1036092': ['nerve growth factor', 'ngf', 'acetylcholinesterase', 'ache'],
#  '1116148': ['nerve growth factor'],
#  '1527053': ['nerve growth factor', 'ngf'],
#  '1647645': ['nerve growth factor'],
#  '192899': ['glucose-6-phosphatase', 'g-6-pase'],
#  '205362': ['glucose-6-phosphatase',
#   'pyruvate carboxylase',
#   'pc',
#   'phosphoenolpyruvate carboxykinase',
#   'pepck',
#   'g6pase'],
#  '230195': ['hex a and b', 'hex'],
#  '240271': ['beta hexosaminidase', 'hex a', 'hex b'],
#  '808963': ['hex a', 'hex b'],
#  '1424119': ['hex a', 'hexa'],
#  '265697': ['ck'],
#  '299239': ['delta-aminolevulinic acid dehydratase',
#   'd-ala-d',
#   'porphobilinogen deaminase',
#   'pbg-d',
#   'ferrochelatase',
#   'fch'],
#  '484541': ['ferrochelatase'],
#  '313695': ['c1 esterase'],
#  '316435': ['viiivwf', 'fab'],
#  '334183': ['c3, c4', 'c3, c4, factor b'],
#  '1245600': ['c3, c4'],
#  '408143': ['cnf'],
#  '616039': ['cnf'],
#  '620450': ['cnf'],
#  '1451338': ['cnf', 'lpl'],
#  '414916': ['c3a'],
#  '1444625': ['c3a', 'c1-inhibitor', 'c1inh'],
#  '435403': ['antithrombin iii', 'at iii'],
#  '1202173': ['antithrombin iii'],
#  '1530443': ['antithrombin iii'],
#  '1569192': ['antithrombin iii',
#   'thrombin',
#   'alpha 1-antitrypsin',
#   'alpha 1-at',
#   'factor xa'],
#  '1649042': ['antithrombin iii', 'at iii', 'fibrinogen', 'prothrombin', 'afp'],
#  '1662049': ['antithrombin iii', 'prothrombin'],
#  '471190': ['acid phosphatase'],
#  '1356945': ['hla-b', 'tnf-beta', 'tnf', 'tumor necrosis factor (tnf)-alpha'],
#  '1359669': ['hla-b',
#   'hla',
#   'hla-drb1',
#   'dqb1',
#   'drb1',
#   'tnf beta',
#   'hla-drb1, -dqa1, -dqb1 and -dpb1',
#   'hla-dpb1'],
#  '1362479': ['hla-b',
#   'hla-dqb1',
#   'hla',
#   'hla-drb1',
#   'tnf-beta',
#   'hla-dqa1',
#   'tumor necrosis factor-beta'],
#  '1672123': ['hla-b', 'bat1', 'bat2'],
#  '481442': ['catalase', 'sod'],
#  '571573': ['hla-a, b, and d'],
#  '573131': ['coagulation factor x', 'thrombin'],
#  '639065': ['a-10'],
#  '650257': ['lcat'],
#  '675210': ['c3-proactivator'],
#  '826588': ['slp'],
#  '919557': ['c3, c3, c4, c3-proactivator', 'alpha 1, alpha 2'],
#  '970989': ['c1q'],
#  '972144': ['alpha1 leads to 2) gal (beta1 leads to 4) glcnac(beta1', 'beta1'],
#  '976312': ['gla', 'mlc'],
#  '1008483': ['uroporphyrinogen i synthetase', 'uro-s'],
#  '1165472': ['uroporphyrinogen i synthetase', 'uro-s'],
#  '1245093': ['uro-s', 'uroporphyrinogen-1-synthetase', 'cytochrome p-450'],
#  '1380483': ['acetylcholinesterase',
#   'ache',
#   'cftr',
#   'bche',
#   'acylcholine acylhydrolase'],
#  '1436650': ['acetylcholinesterase',
#   'nerve growth factor receptor',
#   'ngf receptor',
#   'choline acetyltransferase',
#   'chat'],
#  '1058495': ['methylmalonyl-coa mutase', 'cbl', 'cbl b', 'cbl c'],
#  '1059104': ['methylmalonyl-coa mutase', 'cbl', 'cbl b', 'cbl c', 'cbl a'],
#  '1516297': ['cbl', 'cblc', 'cbld', 'cble', 'methionine synthase'],
#  '1283476': ['growth hormone', 'growth hormone-releasing hormone', 'ghrh'],
#  '1621480': ['growth hormone',
#   'somatotropin',
#   'igf-1',
#   'igf-2',
#   'igf-binding protein-1'],
#  '1122632': ['cystathionine beta-synthase'],
#  '1136541': ['retinol-binding protein', 'rbp'],
#  '1185743': ['c4, c3'],
#  '1211127': ['somatotropin'],
#  '1279436': ['cftr', 'cystic fibrosis transmembrane conductance regulator'],
#  '1279437': ['cftr', 'cystic fibrosis transmembrane conductance regulator'],
#  '1279809': ['cftr'],
#  '1281035': ['cftr'],
#  '1282016': ['cftr'],
#  '1282296': ['cftr', 'cystic fibrosis transmembrane conductance regulator'],
#  '1282304': ['cftr', 'tau'],
#  '1283148': ['cftr', 'cystic fibrosis transmembrane conductance regulator'],
#  '1283149': ['cftr', 'cystic fibrosis transmembrane conductance regulator'],
#  '1283151': ['cftr', 'cystic fibrosis transmembrane conductance regulator'],
#  '1284477': ['cftr'],
#  '1284534': ['cftr', 'cystic fibrosis transmembrane conductance regulator'],
#  '1284535': ['cftr', 'cystic fibrosis transmembrane conductance regulator'],
#  '1284539': ['cftr', 'cf transmembrane conductance regulator'],
#  '1284540': ['cftr', 'cystic fibrosis transmembrane conductance regulator'],
#  '1284548': ['cftr',
#   'cystic fibrosis (cf) transmembrane conductance regulator'],
#  '1285365': ['cftr', 'cystic fibrosis transmembrane conductance regular'],
#  '1286796': ['cftr', 'ttr'],
#  '1302038': ['cftr'],
#  '1308055': ['cftr', 'cystic fibrosis transmembrane conductance regulator'],
#  '1322048': ['cftr', 'cystic fibrosis transmembrane conductance regulator'],
#  '1354866': ['cftr'],
#  '1367855': ['cftr'],
#  '1370301': ['cftr', 'cystic fibrosis transmembrane conductance regulator'],
#  '1370353': ['cftr'],
#  '1370365': ['cftr'],
#  '1370488': ['cftr', 'cystic fibrosis transmembrane conductance regulator'],
#  '1370653': ['cftr', 'cystic fibrosis transmembrane conductance regulator'],
#  '1370807': ['cftr', 'cystic fibrosis transmembrane conductance regulator'],
#  '1371263': ['cftr'],
#  '1371598': ['cftr', 'p-glycoprotein', 'mdr1'],
#  '1372253': ['cftr',
#   'cystic fibrosis transmembrane conductance regulator',
#   'gcl'],
#  '1372891': ['cftr',
#   'cystic fibrosis transmembrane conductance regulator',
#   'p-66',
#   'p-67'],
#  '1373908': ['cftr', 'cystic fibrosis transmembrane conductance regulator'],
#  '1375156': ['cftr',
#   'p-glycoprotein',
#   'mdr1',
#   'cystic-fibrosis transmembrane-conductance regulator'],
#  '1375186': ['cftr', 'cystic fibrosis transmembrane conductance regulator'],
#  '1375432': ['cftr', 'cystic fibrosis transmembrane conductance regulator'],
#  '1375475': ['cftr', 'cystic fibrosis transmembrane conductance regulator'],
#  '1376016': ['cftr', 'cf transmembrane conductance regulator'],
#  '1376017': ['cftr', 'cf transmembrane conductance regulator'],
#  '1376182': ['cftr', 'cystic fibrosis transmembrane conductance regulator'],
#  '1377133': ['cftr', 'cystic fibrosis transmembrane conductance regulator'],
#  '1377140': ['cftr', 'p-glycoprotein'],
#  '1377165': ['cftr',
#   'cystic fibrosis transmembrane conductance regulator',
#   'c-met'],
#  '1377659': ['cftr', 'cystic fibrosis transmembrane conductance regulator'],
#  '1377674': ['cftr',
#   'cystic fibrosis transmembrane conductance regulator',
#   'pkg',
#   'calcium/calmodulin-dependent protein kinase i'],
#  '1377820': ['cftr',
#   'cystic fibrosis transmembrane conductance regulator',
#   'cf transmembrane conductance regulator'],
#  '1378393': ['cftr', 'alpha 1-antitrypsin', 'sucrase-isomaltase'],
#  '1378801': ['cftr',
#   'cystic fibrosis transmembrane conductance regulator',
#   'cf transmembrane conductance regulator'],
#  '1378835': ['cftr', 'cystic fibrosis transmembrane conductance regulator'],
#  '1378998': ['cftr',
#   'cystic fibrosis transmembrane conductance regulator',
#   'mdr-1'],
#  '1379210': ['cftr', 'cystic fibrosis transmembrane conductance regulator'],
#  '1379211': ['cftr'],
#  '1379244': ['cftr', 'cystic fibrosis transmembrane conductance regulator'],
#  '1379413': ['cftr', 'cystic fibrosis transmembrane conductance regulator'],
#  '1379473': ['cftr', 'cystic fibrosis transmembrane conductance regulator'],
#  '1379613': ['cftr', 'cystic fibrosis transmembrane conductance regulator'],
#  '1380486': ['cftr',
#   'cystic fibrosis (cf) transmembrane conductance regulator'],
#  '1380673': ['cftr'],
#  '1380723': ['cftr', 'cystic fibrosis transmembrane conductance regulator'],
#  '1380724': ['cftr', 'cystic fibrosis transmembrane conductance regulator'],
#  '1380943': ['cftr'],
#  '1381723': ['cftr',
#   'cystic fibrosis transmembrane conductance regulator',
#   'cystic fibrosis conductance transmembrane regulator'],
#  '1382222': ['cftr', 'cystic fibrosis transmembrane conductance regulator'],
#  '1382316': ['cftr', 'cystic fibrosis transmembrane conductance regulator'],
#  '1382860': ['cftr', 'p-glycoprotein'],
#  '1384582': ['cftr', 'cystic fibrosis transmembrane conductance regulator'],
#  '1385213': ['cftr', 'cystic fibrosis transmembrane conductance regulator'],
#  '1425485': ['cftr', 'p-glycoprotein'],
#  '1450460': ['cftr'],
#  '1536179': ['cftr', 'cystic fibrosis transmembrane conductance regulator'],
#  '1545831': ['cftr'],
#  '1279646': ['psa', 'cathepsin-d', 'ps2', 'cap = 1'],
#  '1281122': ['g-csf', 'interleukin-2'],
#  '1345744': ['interleukin-2',
#   'interleukin-4',
#   'il-4',
#   'il-2',
#   'cd4',
#   'tnf-alpha',
#   'ifn-gamma',
#   'tnf',
#   'interferon-gamma',
#   'cd8'],
#  '1355612': ['interleukin-2',
#   'il-2',
#   'il-6',
#   'interleukin-6',
#   'cd2',
#   'lfa-3',
#   'interleukin-2 receptor',
#   'il-2r'],
#  '1457282': ['interleukin-2',
#   'interleukin-4',
#   'cd4',
#   'hla-dqb1',
#   'interleukin-6',
#   'icam-1',
#   'transforming growth factor-beta',
#   'pm-scl',
#   'intercellular adhesion molecule 1',
#   'lymphocyte function-associated antigen 1',
#   'endothelial leukocyte adhesion molecule 1'],
#  '1457511': ['interleukin-2',
#   'p53',
#   'epidermal growth factor receptor',
#   'transforming growth factor-alpha',
#   'interferon-gamma',
#   'interleukin-6',
#   'her-2/neu',
#   'interleukin-1',
#   'tumor necrosis factor-alpha',
#   'transforming growth factor-beta',
#   'c-erb b-2',
#   'c-fms'],
#  '1462123': ['interleukin-2',
#   'interleukin-4',
#   'c-myc',
#   'interferon-gamma',
#   'interleukin-6',
#   'cd25',
#   'interleukin-3',
#   'interleukin-2, -3, -4, -6',
#   'proto-oncogene c-myc'],
#  '1546902': ['interleukin-2', 'il-2'],
#  '1554358': ['interleukin-2', 'il-2'],
#  '1281692': ['interleukin-4',
#   'il-4',
#   'ltk',
#   'cdw32',
#   'il-2',
#   'il-1 alpha',
#   'il-6',
#   'transforming growth factor beta'],
#  '1498097': ['il-4', 'il-2', 'tnf-alpha', 'ifn-gamma', 'ige'],
#  '1564938': ['il-4',
#   'il-2',
#   'il-6',
#   'il-1 beta',
#   'gm-csf',
#   'tumor necrosis factor',
#   'tnf',
#   'interleukin (il) 1 alpha',
#   'il-3',
#   'il-5'],
#  '1292640': ['il-2',
#   'il-6',
#   'cd4',
#   'il-1 beta',
#   'tnf-alpha',
#   'ifn-gamma',
#   'gm-csf',
#   'fibrinogen'],
#  '1424744': ['il-2',
#   'il-6',
#   'il-1',
#   'tnf',
#   'interleukin 6',
#   'interleukin 1 (il-1',
#   'interleukin 2',
#   'tumour necrosis factor'],
#  '1540977': ['il-2', 'il-6', 'tnf alpha', 'interferon gamma', 'ifn gamma'],
#  '1598026': ['il-2',
#   'gfap',
#   'interleukin 2',
#   'glial fibrillary acidic protein'],
#  '1304740': ['il-1 alpha',
#   'il-6',
#   'il-1 beta',
#   'tnf-alpha',
#   'ifn-gamma',
#   'interleukin-1 alpha',
#   'ifn-alpha',
#   'il-2-receptor',
#   'il-1',
#   'ifn-y'],
#  '1358037': ['il-1 alpha',
#   'il-6',
#   'il-1 beta',
#   'tnf alpha',
#   'tumour necrosis factor (tnf) alpha',
#   'interleukin 6'],
#  '1628450': ['il-1 alpha',
#   'il-6',
#   'il-1 beta',
#   'tumor necrosis factor alpha',
#   'interleukin-1 beta',
#   'interleukin-1 alpha',
#   'tnf alpha',
#   'interleukin-6'],
#  '1630052': ['il-1 alpha',
#   'il-1 beta',
#   'tumor necrosis factor alpha',
#   'interleukin-1 alpha',
#   'il-1',
#   'tnf',
#   'tnf alpha',
#   'alpha 1 protease inhibitor'],
#  '1370661': ['il-6',
#   'alpha 1-antitrypsin',
#   'interleukin-6',
#   'interleukin 6',
#   'c-reactive protein'],
#  '1376492': ['il-6', 'interleukin-6'],
#  '1380241': ['il-6', 'interleukin-6', 'il-6r', 'gp130', 'nf-il6'],
#  '1384103': ['il-6', 'interleukin-6', 'c-reactive protein', 'crp', 'renin'],
#  '1393846': ['il-6', 'interleukin-6'],
#  '1418006': ['il-6', 'il-1', 'interleukin-6', 'matrix metalloproteinase 1'],
#  '1445805': ['il-6',
#   'tnf-alpha',
#   'tgf-beta',
#   'tumor necrosis factor-alpha',
#   'transforming growth factor-beta'],
#  '1457747': ['il-6', 'interleukin-6'],
#  '1458703': ['il-6',
#   'interleukin-6',
#   'interleukin 6',
#   'c reactive protein',
#   'hgf'],
#  '1467486': ['il-6',
#   'il-1 beta',
#   'interleukin-6',
#   'tumor necrosis factor-alpha'],
#  '1483312': ['il-6', 'interleukin-6'],
#  '1518181': ['il-6', 'interleukin-6', 'c-reactive protein', 'crp'],
#  '1531188': ['il-6', 'cd14'],
#  '1556695': ['il-6', 'interleukin 6'],
#  '1556702': ['il-6', 'interleukin 6', 'c-reactive protein'],
#  '1572693': ['il-6',
#   'tnf-alpha',
#   'ifn-gamma',
#   'interferon-gamma',
#   'interleukin-6'],
#  '1601643': ['il-6',
#   'il-1 beta',
#   'interleukin-1 beta',
#   'tnf alpha',
#   'interferon-gamma',
#   'interleukin-6',
#   'tumor necrosis factor-alpha'],
#  '1634763': ['il-6', 'cd4', 'il-1 beta', 'ril-1 beta', 'ril-2'],
#  '1643291': ['il-6', 'interleukin-6'],
#  '1652755': ['il-6', 'p53', 'il-1', 'interleukin 6', 'c-fos'],
#  '1667942': ['il-6',
#   'tnf-alpha',
#   'il-1',
#   'interleukin-6',
#   'interleukin 6',
#   'tumor necrosis factor-alpha',
#   'interleukin 1'],
#  '1281711': ['gfap', 'ck bb'],
#  '1469442': ['gfap'],
#  '1282007': ['cd4', 'l-selectin', 'vla-1'],
#  '1449258': ['cd4',
#   'cd8',
#   'cd2',
#   'cd10',
#   'cd19',
#   'cd20',
#   'cd21',
#   'cd22',
#   'cd23',
#   'cd38',
#   'cd25',
#   'cd30',
#   'cd71',
#   'cd1',
#   'cd5',
#   'cd7'],
#  '1485949': ['cd4', 'dqa1', 'dqb1'],
#  '1517579': ['cd4', 'ifn-gamma'],
#  '1672546': ['cd4',
#   'il-2r',
#   'anti-interleukin 2 receptor',
#   'igg1',
#   'igg2a',
#   'igg2b'],
#  '1285328': ['p53'],
#  '1295480': ['p53', 'estrogen receptor'],
#  '1302561': ['p53'],
#  '1304832': ['p53', 'c-myc', 'c-erbb-2', 'neu'],
#  '1310070': ['p53'],
#  '1310251': ['p53'],
#  '1311061': ['p53'],
#  '1312696': ['p53'],
#  '1312700': ['p53'],
#  '1312896': ['p53'],
#  '1314165': ['p53', 'gal4'],
#  '1322237': ['p53'],
#  '1323096': ['p53',
#   'c-erbb-2',
#   'estrogen/progesterone receptors',
#   'er',
#   'pgr'],
#  '1324796': ['p53'],
#  '1327031': ['p53',
#   'epidermal growth factor receptor',
#   'egfr',
#   'erbb2',
#   'transforming growth factor-alpha',
#   'tgf-alpha',
#   'k-ras'],
#  '1331352': ['p53'],
#  '1333465': ['p53'],
#  '1334053': ['p53', 'c-myc'],
#  '1336726': ['p53', 'tumor-suppressor', 'rb-1'],
#  '1347094': ['p53', 'ki-ras'],
#  '1348931': ['p53'],
#  '1352359': ['p53', 'estrogen receptor', 'c-erbb-2', 'erbb2'],
#  '1353190': ['p53'],
#  '1353891': ['p53', 'all 3'],
#  '1355662': ['p53', 'c-erbb-2', 'epidermal growth factor receptor', 'egfr'],
#  '1357342': ['p53'],
#  '1358031': ['p53', 'c-myc', 'c-erbb-2', 'k-ras', 'her-2/neu', 'dcc'],
#  '1359493': ['p53'],
#  '1360329': ['p53', 'c-erbb-2'],
#  '1361656': ['p53'],
#  '1373500': ['p53', 'hsp70'],
#  '1373881': ['p53'],
#  '1394133': ['p53'],
#  '1394234': ['p53'],
#  '1398068': ['p53', 'mck'],
#  '1413493': ['p53'],
#  '1419981': ['p53'],
#  '1423285': ['p53'],
#  '1429209': ['p53'],
#  '1433368': ['p53'],
#  '1453267': ['p53', 'retinoblastoma (rb)'],
#  '1467311': ['p53'],
#  '1468776': ['p53', 'estrogen receptor', 'neu', 'progesterone receptor'],
#  '1486864': ['p53', 'h-ras-1', 'l-myc'],
#  '1511156': ['p53'],
#  '1516030': ['p53'],
#  '1519492': ['p53'],
#  '1525830': ['p53'],
#  '1537617': ['p53', 'c-erbb-2'],
#  '1557756': ['p53'],
#  '1559236': ['p53'],
#  '1565143': ['p53'],
#  '1565469': ['p53'],
#  '1567185': ['p53', 'rb1', 'p21'],
#  '1569122': ['p53'],
#  '1569604': ['p53'],
#  '1570151': ['p53'],
#  '1581912': ['p53'],
#  '1586628': ['p53', 'epidermal growth factor receptor'],
#  '1587536': ['p53'],
#  '1591284': ['p53', 'nf-1'],
#  '1593647': ['p53'],
#  '1617667': ['p53', 'progesterone receptor'],
#  '1622629': ['p53'],
#  '1631137': ['p53'],
#  '1644930': ['p53'],
#  '1648702': ['p53'],
#  '1649734': ['p53', 'k-ras'],
#  '1656362': ['p53'],
#  '1673792': ['p53'],
#  '1314136': ['gastrin-releasing peptide',
#   'vasopressin',
#   'bombesin',
#   'bradykinin',
#   'cholecystokinin',
#   'neurotensin'],
#  '1533481': ['vasopressin', 'acth'],
#  '1296800': ['il-1 beta',
#   'tnf-alpha',
#   'tumor necrosis factor alpha',
#   'interleukin-1 beta'],
#  '1376258': ['il-1 beta',
#   'tnf-alpha',
#   'il-1',
#   'interleukin-1',
#   'tumor necrosis factor-alpha',
#   'interleukin (il)-1',
#   'cd11a',
#   'cd11b'],
#  '1329840': ['tnf-alpha', 'tumor necrosis factor', 'tnf-beta', 'tnf'],
#  '1374096': ['tnf-alpha',
#   'vcam-1',
#   'icam-1',
#   'vascular cell adhesion molecule-1',
#   'beta 2',
#   'beta 1 integrins'],
#  '1484608': ['tnf-alpha',
#   'tumor necrosis factor alpha',
#   'tumor necrosis factor-alpha',
#   'cachectin'],
#  '1575548': ['tnf-alpha'],
#  '1421423': ['estrogen receptor', 'igf-ii', 'igf-i'],
#  '1342640': ['tumor necrosis factor alpha', 'tnf alpha'],
#  '1346144': ['tumor necrosis factor alpha',
#   'dr3',
#   'tnf',
#   'tnf alpha',
#   'tumor necrosis factor beta',
#   'tnf beta',
#   'histocompatibility leucocyte antigens (hla)-b',
#   'tsh-receptor'],
#  '1301949': ['n-acetylgalactosamine-4-sulfatase'],
#  '1302030': ['pax6', 'pax-6'],
#  '1334370': ['pax-6', 'an2', 'wt1'],
#  '1347148': ['pax-6', 'pax-3', 'splotch', 'pax'],
#  '1303194': ['tcof1'],
#  '1614874': ['ifn-alpha',
#   'interferon-alpha',
#   'irf-1',
#   'interferon-alpha 4',
#   'ifn-alpha 4',
#   'ifn-alpha 6',
#   'alpha f1',
#   'interferon regulatory factor 1',
#   'ifn-alpha 4 and -alpha 6',
#   'interferon stimulated (isg)-15'],
#  '1325950': ['c-myc',
#   'neu',
#   'igf-i',
#   'pgr',
#   'progesterone receptor',
#   'egf-r',
#   'insulin-like growth-factor-i receptors',
#   'igf-i-r',
#   'her2'],
#  '1563831': ['c-myc', 'l-myc', 'myc', 'n-myc'],
#  '1363518': ['c-erbb-2'],
#  '1377893': ['c-erbb-2'],
#  '1310798': ['insulin-like growth factor-ii', 'igf-ii', 'igf-i'],
#  '1381703': ['igf-ii',
#   'igf-i',
#   'insulin-like growth factor (igf)-i',
#   'igfbp-1',
#   'insulin-like growth factor-type i (igf-i',
#   'igfbps'],
#  '1421422': ['igf-ii', 'igf-i'],
#  '1672092': ['igf-ii', 'igf-i'],
#  '1312561': ['cav'],
#  '1312569': ['insulin-like growth factor i'],
#  '1312643': ['int-3', 'notch', 'cdc-10'],
#  '1314761': ['calmodulin'],
#  '1315406': ['retinoic acid receptor alpha', 'retinoic acid receptor beta'],
#  '1316273': ['cln3', 'cdc28', 'cln1', 'cln2', 'cdc34'],
#  '1317471': ['pick', 'ncf-1', 'ncf-47k', 'gp91-phox', 'p22-phox', 'p47-phox'],
#  '1318786': ['ssl2', 'his4', 'ercc-3', 'ssl1'],
#  '1321346': ['ocrl'],
#  '1491459': ['ocrl',
#   'carbonic anhydrase ii',
#   'ca ii',
#   'oculocerebrorenal syndrome of lowe'],
#  '1528013': ['ocrl'],
#  '1324601': ['dr3'],
#  '1440568': ['dr3', 'dqa1', 'dqb1', 'drb1', 'hla-dqa1', 'dr4'],
#  '1477090': ['dr3',
#   'hla',
#   'hla-drb1',
#   'dqa1',
#   'dqb1',
#   'drb1',
#   'dr4',
#   'dq2',
#   'iddm'],
#  '1485950': ['dr3', 'dqa1', 'dqb1', 'dr4'],
#  '1548146': ['dr3', 'dqa1', 'dqb1', 'dr4', 'dqb'],
#  '1373310': ['progesterone receptor', 'erbb2', 'tp53'],
#  '1326003': ['hla-dqb1', 'hla', 'hla-drb1', 'dqa1', 'dqb1', 'drb1'],
#  '1556182': ['hla-dqb1', 'hla', 'dqb1', 'dr4', 'dr5', 'dr1'],
#  '1565247': ['hla-dqb1', 'dqb1', 'dqb'],
#  '1440567': ['hla', 'hla-drb1', 'dqa1', 'dqb1', 'drb1', 'dr5'],
#  '1672728': ['hla-drb1', 'drb1', 'b18', 'sco1'],
#  '1349786': ['dqa1', 'hla-dqa1'],
#  '1358911': ['dqa1', 'dqb1'],
#  '1421173': ['k-ras', 'n-ras'],
#  '1329504': ['pdeb'],
#  '1338765': ['pdeb'],
#  '1329505': ['col10a1'],
#  '1556897': ['tumor necrosis factor', 'tnf', 'tnf alpha'],
#  '1378089': ['tnf', 'rtnf'],
#  '1602292': ['tnf',
#   'interleukin-6',
#   'interleukin 6',
#   'il6',
#   'tcii',
#   'tci and iii'],
#  '1330402': ['alpha 1-antitrypsin'],
#  '1357424': ['alpha 1-antitrypsin'],
#  '1411288': ['alpha 1-antitrypsin', 'calprotectin (l1'],
#  '1437795': ['alpha 1-antitrypsin', 'a-1--at'],
#  '1642448': ['alpha 1-antitrypsin'],
#  '1331389': ['vitamin d receptor', 'parathyroid hormone'],
#  '1335319': ['vitamin d receptor', 'vdr'],
#  '1336301': ['vitamin d receptor', 'vdr', 'pddr', 'vdd1', 'col2a1', 'ela1'],
#  '1652893': ['vitamin d receptor', 'vitamin d3 receptor'],
#  '1332524': ['lp(a)',
#   'apolipoproteins a-1 and b',
#   'apolipoprotein a-i',
#   'apolipoprotein b',
#   'apolipoprotein a-i/b'],
#  '1332926': ['elastin'],
#  '1333377': ['lamp1', 'lamp2'],
#  '1505982': ['an2', 'acid phosphatase-1', 'acp1', 'apob'],
#  '1353665': ['col2a1'],
#  '1429602': ['col2a1', 'collagen alpha 1(ii) chain'],
#  '1671807': ['col2a1'],
#  '1534143': ['p107', 'p300', 'nf-kappa b'],
#  '1345166': ['n-cadherin', 'bcr', 'glutathione-s-transferase'],
#  '1638632': ['n-cadherin', 'e-cadherin', 'alpha n-catenin', 'beta-catenin'],
#  '1544169': ['interferon-gamma', 'interleukin 6', 'il6'],
#  '1346083': ['retinoblastoma', 'nf 1'],
#  '1405404': ['retinoblastoma'],
#  '1346589': ['rb1', 'tp53', 'mycn'],
#  '1591732': ['tp53'],
#  '1553789': ['ki-ras', 'n-ras'],
#  '1554414': ['ki-ras', 'gas-3'],
#  '1582509': ['ki-ras', 'p21'],
#  '1347297': ['col7a1'],
#  '1358979': ['col7a1', 'collagen vii'],
#  '1377750': ['col7a1'],
#  '1349842': ['oat', 'int-2', 'cyp2e-1'],
#  '1362387': ['psti',
#   'alcohol dehydrogenase',
#   'adh4',
#   'adh5',
#   'adh',
#   'adh1',
#   'formaldehyde dehydrogenase',
#   'fdh',
#   'adh2',
#   'adh3'],
#  '1352685': ['c4a and c4b', 'c4b'],
#  '1421624': ['c4b', 'hla-a, b, c) of class ii'],
#  '1469300': ['c4b'],
#  '1550412': ['c4b', 'hla-a, b, c', 'dr1'],
#  '1352745': ['cr1', 'c3br'],
#  '1512827': ['interleukin-6'],
#  '1622424': ['interleukin-6'],
#  '1637886': ['interleukin-6'],
#  '1673843': ['cd2'],
#  '1360084': ['comt'],
#  '1363589': ['cytochrome oxidase subunit i',
#   'coi',
#   'nadh dehydrogenase subunit 6',
#   'nd6'],
#  '1370306': ['pg-ii'],
#  '1371277': ['hlyb', 'ste6', 'hlya'],
#  '1373503': ['transforming growth factor beta 2',
#   'tgf-beta',
#   'tgf-beta 2',
#   'tgf-beta 1',
#   'tgf-beta 3'],
#  '1673033': ['tgf-beta',
#   'tgf-beta 1',
#   'transforming growth factor beta 1',
#   'retinoblastoma gene product (p105)',
#   'p60',
#   'p60/p105/'],
#  '1386607': ['hexb'],
#  '1390948': ['hexb', 'alpha- and a beta'],
#  '1532910': ['hexb', 'hexa', 'beta-hexosaminidase'],
#  '1400901': ['anti-pyruvate dehydrogenase', 'pdh'],
#  '1404883': ['ornithine transcarbamylase'],
#  '1415186': ['5-aminolevulinate synthase',
#   'alas',
#   'alpha and beta globin',
#   'glycophorin a'],
#  '1417119': ['mig', 'hla-b27'],
#  '1419500': ['dr4'],
#  '1419753': ['e-cadherin'],
#  '1486691': ['interleukin 2', 'il-2) receptor'],
#  '1427899': ['hxb',
#   'gelsolin',
#   'gsn',
#   'adenylate kinase 1',
#   'ak1',
#   'arginosuccinate synthetase',
#   'ass',
#   'abl',
#   'abl1',
#   'abo blood group',
#   'abo',
#   'dopamine beta-hydroxylase',
#   'dbh',
#   'xpa',
#   'dyt1',
#   'tsc1'],
#  '1639411': ['ak1', 'abo', 'dyt1', 'tsc1'],
#  '1429035': ['hla-dqa and -dqb', 'dqb'],
#  '1433335': ['ercc1', 'ercc2'],
#  '1437145': ['ret', 'ptc-1', 'ptc-2'],
#  '1439760': ['a beta'],
#  '1439810': ['microsomal triglyceride transfer protein', 'mtp'],
#  '1446625': ['calcitonin gene-related peptide', 'cgrp'],
#  '1447574': ['agm1'],
#  '1454059': ['nucleolin', 'histone h1'],
#  '1454518': ['ercc3', 'sd4', 'sd2'],
#  '1455194': ['protein c'],
#  '1457041': ['nf1', 'neurofibromatosis type 1', 'ira1', 'ira2'],
#  '1589758': ['sbma'],
#  '1463007': ['cytochrome b'],
#  '1463017': ['friedreich ataxia locus', 'frda'],
#  '1463019': ['liver-type arginase'],
#  '1475034': ['dopamine d2 receptor', 'drd2'],
#  '1478642': ['drd2',
#   'd2 dopamine receptor',
#   'neural cell adhesion molecule',
#   'ncam',
#   'apoai',
#   'stmy'],
#  '1481629': ['csf'],
#  '1490631': ['gp 46'],
#  '1491483': ['osteocalcin'],
#  '1492799': ['aldh2'],
#  '1515089': ['cathepsin b', 'cat b', 'cat l', 'cathepsin d'],
#  '1537354': ['cblc'],
#  '1517763': ['hmsn i and hmsn ii', 'cmt 1', 'cmt 2'],
#  '1525248': ['alpha 1-antiproteinase'],
#  '1525624': ['cartilage oligomeric matrix protein', 'comp'],
#  '1528363': ['igg3'],
#  '1601008': ['igg3'],
#  '1532632': ['beta-hexosaminidase'],
#  '1536955': ['neurofibromatosis, type 1', 'nf-1'],
#  '1571407': ['interferon (ifn)-alpha', 'ifn-alpha 2b'],
#  '1578514': ['amyloid precursor protein'],
#  '1635670': ['amyloid precursor protein', 'beta amyloid precursor protein'],
#  '1582608': ['alpha 1 antitrypsin'],
#  '1604230': ['hla b27'],
#  '1609264': ['neutrophil elastase'],
#  '1611773': ['succinate dehydrogenase', 'sdh'],
#  '1628431': ['sca1'],
#  '1634229': ['sphingolipid activator protein 1', 'sap-1', 'prosaposin'],
#  '1634353': ['nd4'],
#  '1635296': ['nd4'],
#  '1637893': ['spam'],
#  '1641053': ['vddr'],
#  '1643619': ['cs'],
#  '1652892': ['gaa', 'styi'],
#  '1662825': ['thymopoietin'],
#  '1670635': ['methylmalonyl coa mutase']}

# %%
# Find co-occurrences of genes in pubmed ids
# For each pmid, find all pairs of concepts

gene_interactions = []
for pmid, concepts in pubmed_to_concepts.items():
    for gene1, gene2 in combinations(concepts, 2):
        if gene1 != gene2:
            gene_interactions.append((gene1, gene2))

# %%
#Remove Redundancy
gene_interactions = set(gene_interactions)
#Intercations
with open('gene_interactions.txt', 'w') as f:
    for gene1, gene2 in gene_interactions:
        f.write(gene1 + " interacts with " + gene2 + "\n")

# %%
len(gene_interactions)
# Out:
# 1831

# %%
with open('gene_interactions.txt', 'r') as file:
    content = file.read()

# Display the file content
print(content)
# Out:
# p53 interacts with mck
# cystic fibrosis transmembrane conductance regulator interacts with mdr-1
# cd71 interacts with cd5
# nf1 interacts with ira2
# p53 interacts with tumor necrosis factor-alpha
# hla-dqa and -dqb interacts with dqb
# p53 interacts with epidermal growth factor receptor
# interleukin-4 interacts with intercellular adhesion molecule 1
# pddr interacts with vdd1
# nadh dehydrogenase subunit 6 interacts with nd6
# insulin interacts with igf-1
# irf-1 interacts with ifn-alpha 4 and -alpha 6
# cd2 interacts with cd1
# dqb1 interacts with leukocyte antigen (hla) dqa1
# cblc interacts with cbld
# pax-6 interacts with pax
# igf-i interacts with pgr
# cathepsin-d interacts with ps2
# insulin interacts with glucagon
# interleukin-6 interacts with endothelial leukocyte adhesion molecule 1
# il-1 alpha interacts with ifn-alpha
# hla interacts with hla-dpb1
# interleukin-4 interacts with interleukin-2, -3, -4, -6
# p53 interacts with gal4
# ki-ras interacts with p21
# cd4 interacts with interferon-gamma
# cbl interacts with methionine synthase
# albumin interacts with tumor necrosis factor-alpha
# p107 interacts with beta-endorphin
# neuropeptide y interacts with acth
# abo interacts with dbh
# adh5 interacts with adh2
# abl1 interacts with dyt1
# dqa1 interacts with dqb
# il-1 beta interacts with tumor necrosis factor alpha
# rbp-2 interacts with igf-i and -ii
# il-2 interacts with glial fibrillary acidic protein
# alpha-1-antitrypsin interacts with crp
# alpha 1-antitrypsin interacts with sucrase-isomaltase
# insulin interacts with adrenocorticotropic hormone
# cr1 interacts with c3br
# il-6 interacts with transforming growth factor beta
# int-3 interacts with notch
# tnf alpha interacts with interleukin-6
# abl interacts with abl1
# cd20 interacts with cd1
# dq2 interacts with iddm
# cd4 interacts with pm-scl
# p53 interacts with egfr
# il-6 interacts with interleukin-2 receptor
# il6 interacts with tcii
# il-1 alpha interacts with tnf alpha
# insulin interacts with rbp-2
# il-2 interacts with tumour necrosis factor
# interferon-alpha 4 interacts with ifn-alpha 6
# ifn-gamma interacts with il-1
# albumin interacts with c-reactive protein
# cd4 interacts with iga-aga
# ps2 interacts with cap = 1
# dqb1 interacts with iddm
# arginosuccinate synthetase interacts with dyt1
# cftr interacts with p-66
# il-1 beta interacts with tumour necrosis factor (tnf) alpha
# dr3 interacts with tnf
# cble interacts with methionine synthase
# cdw32 interacts with il-1 alpha
# pddr interacts with ela1
# alpha-1-antitrypsin interacts with fibrinogen
# interleukin-6 interacts with il6
# insulin interacts with p107
# lymphocyte function-associated antigen 1 interacts with endothelial leukocyte adhesion molecule 1
# il-6 interacts with tumor necrosis factor alpha
# cd25 interacts with interleukin-2, -3, -4, -6
# tumor necrosis factor alpha interacts with interleukin-1 beta
# c-myc interacts with her-2/neu
# adh interacts with adh3
# her-2/neu interacts with interleukin-1
# ste6 interacts with hlya
# growth hormone interacts with somatotropin
# phosphoenolpyruvate carboxykinase interacts with pepck
# grp interacts with vasopressin
# d2 dopamine receptor interacts with apoai
# her-2/neu interacts with transforming growth factor-beta
# pgr interacts with igf-i-r
# tnf interacts with tci and iii
# psti interacts with fdh
# ak1 interacts with abo
# galactokinase interacts with galk
# abo interacts with dyt1
# cd4 interacts with cd19
# adenylate kinase 1 interacts with abo blood group
# an2 interacts with acid phosphatase-1
# cln1 interacts with cdc34
# arylsulfatase a interacts with mitochondrial aconitase
# drd2 interacts with apoai
# thrombin interacts with factor xa
# ssl2 interacts with ssl1
# antithrombin interacts with iga
# lp(a) interacts with apolipoprotein a-i/b
# delta-aminolevulinic acid dehydratase interacts with porphobilinogen deaminase
# cd4 interacts with cd20
# il-1 alpha interacts with il-1
# ercc-3 interacts with ssl1
# il-6 interacts with interleukin 2
# bombesin interacts with cholecystokinin
# nerve growth factor interacts with igf-i
# tpo interacts with tsh receptor
# catalase interacts with sod
# gelsolin interacts with dbh
# ril-1 beta interacts with ril-2
# gastrin-releasing peptide interacts with vasopressin
# gm-csf interacts with interleukin (il) 1 alpha
# mdr1 interacts with cystic-fibrosis transmembrane-conductance regulator
# transforming growth factor-alpha interacts with tumor necrosis factor-alpha
# pick interacts with ncf-47k
# nerve growth factor receptor interacts with ngf receptor
# dqb1 interacts with dq2
# il-1 beta interacts with il-3
# c reactive protein interacts with hgf
# somatotropin interacts with igf-2
# phenylalanine hydroxylase interacts with albumin
# cd2 interacts with lfa-3
# interleukin-1 beta interacts with interleukin-1 alpha
# drb1 interacts with dr5
# serum albumin interacts with hex a- and hex b-)
# interleukin-2 interacts with il-2
# cd4 interacts with cd30
# androgen receptor interacts with tfm
# gelsolin interacts with gsn
# cd4 interacts with hla-dqb1
# interleukin-4 interacts with interferon-gamma
# transforming growth factor-beta interacts with c-fms
# icam-1 interacts with transforming growth factor-beta
# dqa1 interacts with drb1
# tnf-alpha interacts with vcam-1
# ifn-alpha interacts with interferon stimulated (isg)-15
# ak1 interacts with dopamine beta-hydroxylase
# iga interacts with il-2r
# apolipoprotein a-i interacts with apolipoprotein b
# insulin interacts with ttr
# cblc interacts with cble
# hxb interacts with xpa
# il-2 interacts with gm-csf
# il-2 interacts with interleukin (il) 1 alpha
# interleukin 2 interacts with il-2) receptor
# ass interacts with xpa
# interleukin-2 interacts with interleukin-4
# neurofibromatosis, type 1 interacts with nf-1
# thrombin interacts with alpha 1-antitrypsin
# delta-aminolevulinic acid dehydratase interacts with ferrochelatase
# dopamine d2 receptor interacts with drd2
# tfm interacts with ta
# acetylcholinesterase interacts with bche
# cd10 interacts with cd22
# adh interacts with adh2
# c-erbb-2 interacts with er
# cystic fibrosis transmembrane conductance regulator interacts with gcl
# hla-b interacts with hla-dpb1
# d2 dopamine receptor interacts with stmy
# cd22 interacts with cd1
# alas interacts with glycophorin a
# il-6 interacts with il-3
# insulin interacts with corticotropin releasing hormone
# insulin interacts with grp
# alpha-1-antitrypsin interacts with viii
# insulin interacts with interleukin 6
# tnf beta interacts with histocompatibility leucocyte antigens (hla)-b
# il-2r interacts with iga-aga
# pick interacts with p22-phox
# tnf alpha interacts with interleukin 6
# cd4 interacts with interleukin 2 receptor
# ifn-alpha 4 interacts with ifn-alpha 4 and -alpha 6
# adh5 interacts with fdh
# cathepsin b interacts with cat l
# hexb interacts with beta-hexosaminidase
# il-6r interacts with gp130
# tnf-beta interacts with tumor necrosis factor-beta
# dr3 interacts with hla-drb1
# drd2 interacts with stmy
# iga interacts with cd8
# il-6 interacts with tnf-alpha
# gp130 interacts with nf-il6
# alpha-1-antitrypsin interacts with alpha 1-antitrypsin
# igf-ii interacts with igf-i and -ii
# col2a1 interacts with ela1
# insulin interacts with igf-ii
# il-4 interacts with il-1 alpha
# avp interacts with acth
# hla-drb1 interacts with dq2
# n-cadherin interacts with glutathione-s-transferase
# cd19 interacts with cd1
# cd25 interacts with proto-oncogene c-myc
# gaa interacts with styi
# hla-dqb1 interacts with dqb
# glucagon interacts with rbp-2
# igf-i interacts with rbp-2
# interleukin-1 alpha interacts with tnf
# il-1 interacts with alpha 1 protease inhibitor
# il-4 interacts with ige
# npy interacts with corticotropin releasing hormone
# il-1 interacts with interleukin-6
# psti interacts with alcohol dehydrogenase
# hlyb interacts with hlya
# ak1 interacts with abl1
# apolipoproteins a-1 and b interacts with apolipoprotein b
# interferon-gamma interacts with il6
# hla-drb1 interacts with dqb1
# tgf-alpha interacts with k-ras
# l-myc interacts with myc
# interferon-alpha 4 interacts with interferon regulatory factor 1
# interleukin-6 interacts with interleukin 6
# interferon-gamma interacts with interleukin-6
# alcohol dehydrogenase interacts with adh3
# cd5 interacts with cd7
# glucagon interacts with p107
# igf-i interacts with p107
# interleukin-6 interacts with intercellular adhesion molecule 1
# ifn-alpha interacts with irf-1
# pick interacts with ncf-1
# cd8 interacts with iga-aga
# avp interacts with crh
# tnf interacts with il6
# pyruvate carboxylase interacts with pc
# ifn-alpha interacts with interferon regulatory factor 1
# thrombin interacts with alpha 1-at
# tumor necrosis factor alpha interacts with tsh-receptor
# interleukin-1 beta interacts with tumor necrosis factor-alpha
# interleukin-6 interacts with interleukin-3
# ak1 interacts with arginosuccinate synthetase
# interleukin-1 beta interacts with tnf alpha
# tnf interacts with alpha 1 protease inhibitor
# hla-dqb1 interacts with dqa1
# il-1 beta interacts with ril-2
# beta hexosaminidase interacts with hex a
# hla interacts with dq2
# tnf interacts with interleukin-6
# tgf-beta interacts with retinoblastoma gene product (p105)
# il-2 interacts with tnf alpha
# interleukin-4 interacts with transforming growth factor beta
# corticotropin releasing hormone interacts with crh
# cd2 interacts with cd23
# methylmalonyl-coa mutase interacts with cbl c
# interleukin (il)-1 interacts with cd11b
# ncam interacts with apoai
# interleukin-2 interacts with pm-scl
# hla interacts with dqb1
# p53 interacts with c-fms
# il-6r interacts with nf-il6
# sap-1 interacts with prosaposin
# interleukin-6 interacts with crp
# growth hormone-releasing hormone interacts with ghrh
# avp interacts with neuropeptide y
# ifn-gamma interacts with interleukin-6
# cd2 interacts with cd21
# acid phosphatase-1 interacts with apob
# cystic fibrosis transmembrane conductance regulator interacts with p-67
# cd8 interacts with cd19
# igf-ii interacts with insulin-like growth factor i
# interleukin-1 alpha interacts with ifn-y
# alpha-1-antitrypsin interacts with alpha 1-at
# ar interacts with sbma
# grp interacts with crh
# insulin interacts with transthyretin
# cd2 interacts with cd71
# rb1 interacts with p21
# c-erbb-2 interacts with neu
# n-cadherin interacts with beta-catenin
# lfa-3 interacts with il-2r
# hla-a interacts with hfe
# cd4 interacts with tnf-alpha
# cbl interacts with cbl c
# igf-2 interacts with igf-binding protein-1
# cd4 interacts with igg2a
# porphobilinogen deaminase interacts with pbg-d
# p53 interacts with c-fos
# hemopexin interacts with ceruloplasmin
# ocrl interacts with carbonic anhydrase ii
# il-1 alpha interacts with ifn-gamma
# cd20 interacts with cd38
# dr4 interacts with iddm
# igf-i interacts with progesterone receptor
# interferon-alpha interacts with interferon stimulated (isg)-15
# her-2/neu interacts with dcc
# il-4 interacts with ifn-gamma
# ache interacts with bche
# glucagon interacts with ttr
# adenylate kinase 1 interacts with xpa
# interleukin-2 interacts with cd4
# acp1 interacts with apob
# cd8 interacts with cd30
# il-2r interacts with interleukin 2 receptor
# tnf alpha interacts with interferon gamma
# gastrin-releasing peptide interacts with crh
# cd20 interacts with cd21
# pick interacts with p47-phox
# alcohol dehydrogenase interacts with adh2
# glucagon interacts with beta-endorphin
# igf-i interacts with beta-endorphin
# acetylcholinesterase interacts with acylcholine acylhydrolase
# ltk interacts with il-1 alpha
# hla-dqb1 interacts with dr1
# hla-dqb1 interacts with drb1
# p53 interacts with l-myc
# il-1 alpha interacts with alpha 1 protease inhibitor
# cblc interacts with methionine synthase
# il-1 alpha interacts with interleukin-6
# cd20 interacts with cd71
# abo blood group interacts with xpa
# cystic fibrosis transmembrane conductance regulator interacts with cf transmembrane conductance regulator
# ercc3 interacts with sd2
# cd4 interacts with anti-interleukin 2 receptor
# irf-1 interacts with ifn-alpha 4
# hla-b interacts with tnf-beta
# cathepsin-d interacts with cap = 1
# tnf alpha interacts with interferon-gamma
# alcohol dehydrogenase interacts with formaldehyde dehydrogenase
# adh interacts with fdh
# hla-dqb1 interacts with transforming growth factor-beta
# tumor necrosis factor alpha interacts with dr3
# il-6 interacts with tumor necrosis factor
# tnf-beta interacts with tnf
# n-cadherin interacts with alpha n-catenin
# tgf-beta interacts with transforming growth factor beta 1
# cftr interacts with calcium/calmodulin-dependent protein kinase i
# cd1 interacts with cd7
# il-6 interacts with hgf
# il-6 interacts with ifn gamma
# hla-drb1 interacts with tnf beta
# p53 interacts with er
# antithrombin iii interacts with a1at
# rbp-1 interacts with igf-i and -ii
# tnf-alpha interacts with tnf-beta
# vdd1 interacts with col2a1
# ercc3 interacts with sd4
# igf-ii interacts with rbp-2
# il-1 interacts with interleukin 6
# tnf-alpha interacts with gm-csf
# dr4 interacts with dq2
# egf-r interacts with insulin-like growth-factor-i receptors
# interleukin-6 interacts with c-erb b-2
# p-66 interacts with p-67
# ifn-alpha interacts with il-2-receptor
# cd4 interacts with l-selectin
# ncf-1 interacts with gp91-phox
# interferon-gamma interacts with interleukin 6
# adh2 interacts with adh3
# cd8 interacts with interleukin 2 receptor
# il-2 interacts with gfap
# cln3 interacts with cdc28
# galactokinase interacts with gk2
# icam-1 interacts with beta 2
# cd8 interacts with cd38
# androgen receptor interacts with psti
# hla-b interacts with hla
# igf-ii interacts with p107
# drb1 interacts with hla-dpb1
# drb1 interacts with b18
# drd2 interacts with ncam
# psa interacts with ps2
# cd2 interacts with il-2r
# interferon-alpha interacts with irf-1
# interferon-gamma interacts with interleukin-3
# estrogen receptor interacts with erbb2
# hla interacts with tnf beta
# tnf interacts with interleukin 6
# il6 interacts with tci and iii
# porphobilinogen deaminase interacts with ferrochelatase
# transforming growth factor-alpha interacts with c-fms
# abl interacts with tsc1
# a1at interacts with viii
# alpha f1 interacts with interferon stimulated (isg)-15
# il-2 interacts with il-1 alpha
# cd8 interacts with cd71
# insulin interacts with hla-drb1
# gfap interacts with glial fibrillary acidic protein
# transferrin interacts with ceruloplasmin
# her-2/neu interacts with tumor necrosis factor-alpha
# neural cell adhesion molecule interacts with apoai
# il-6 interacts with il-1 beta
# il-2 interacts with ige
# tumor necrosis factor alpha interacts with interleukin-1 alpha
# p107 interacts with igf-i and -ii
# il-2r interacts with igg2a
# cd2 interacts with cd5
# vasopressin interacts with avp
# tnf-alpha interacts with ifn-alpha
# insulin interacts with rbp-1
# cd4 interacts with dqa1
# tumor necrosis factor interacts with tnf-beta
# c-erbb-2 interacts with dcc
# cd22 interacts with cd38
# d2 dopamine receptor interacts with neural cell adhesion molecule
# gal-1 interacts with gal-1-put
# hla-b interacts with dqb1
# tumor necrosis factor interacts with interleukin (il) 1 alpha
# tumor-suppressor interacts with rb-1
# hla-drb1 interacts with dr5
# adenylate kinase 1 interacts with abo
# adh1 interacts with adh3
# cd38 interacts with cd30
# albumin interacts with a1at
# gastrin-releasing peptide interacts with neurotensin
# fibrinogen interacts with crp
# lp(a) interacts with apolipoprotein b
# vasopressin interacts with neurotensin
# drd2 interacts with neural cell adhesion molecule
# galactokinase interacts with gk1
# cd21 interacts with cd30
# ars(a) interacts with ars(b)
# ache interacts with acylcholine acylhydrolase
# interleukin-4 interacts with cd8
# interleukin-4 interacts with cd25
# abo blood group interacts with abo
# e-cadherin interacts with alpha n-catenin
# pgr interacts with progesterone receptor
# il-1 interacts with tnf
# gsn interacts with xpa
# cd23 interacts with cd25
# insulin interacts with hla-dqb1
# p53 interacts with neu
# cd22 interacts with cd71
# il-2r interacts with anti-interleukin 2 receptor
# cd20 interacts with cd5
# dqa1 interacts with dqb1
# cathepsin b interacts with cathepsin d
# insulin interacts with igf-i
# il-1 alpha interacts with interleukin 6
# cftr interacts with cystic-fibrosis transmembrane-conductance regulator
# cd19 interacts with cd23
# insulin-like growth factor-ii interacts with igf-ii
# tfm interacts with tabby
# ass interacts with dbh
# il-6 interacts with matrix metalloproteinase 1
# vcam-1 interacts with beta 2
# cd8 interacts with cd7
# ak1 interacts with abo blood group
# irf-1 interacts with ifn-alpha 6
# friedreich ataxia locus interacts with frda
# interleukin (il) 1 alpha interacts with il-5
# cd19 interacts with cd21
# hla interacts with dr5
# alpha 1-antitrypsin interacts with calprotectin (l1
# ifn-alpha interacts with interferon-alpha 4
# hla-dqa1 interacts with dr4
# vitamin d receptor interacts with vdd1
# cd19 interacts with cd71
# tnf-alpha interacts with il-2-receptor
# ifn-gamma interacts with fibrinogen
# il-2 interacts with ifn-gamma
# somatotropin interacts with igf-1
# cd25 interacts with cd5
# neural cell adhesion molecule interacts with stmy
# bche interacts with acylcholine acylhydrolase
# acetylcholinesterase interacts with ngf receptor
# calcitonin gene-related peptide interacts with cgrp
# erbb2 interacts with tgf-alpha
# interleukin-6 interacts with interleukin-2 receptor
# cd21 interacts with cd38
# interferon-gamma interacts with c-erb b-2
# pax-6 interacts with splotch
# interferon regulatory factor 1 interacts with ifn-alpha 4 and -alpha 6
# alpha f1 interacts with interferon regulatory factor 1
# interleukin-2 interacts with tnf-alpha
# adh4 interacts with adh3
# alpha- and beta-galactosidase interacts with beta mannosidase
# alpha 1-at interacts with factor xa
# pddr interacts with col2a1
# nerve growth factor receptor interacts with choline acetyltransferase
# cd4 interacts with transforming growth factor-beta
# ifn-gamma interacts with tnf
# cftr interacts with cystic fibrosis conductance transmembrane regulator
# interleukin 1 (il-1 interacts with interleukin 2
# neu interacts with igf-i-r
# ifn-alpha 6 interacts with interferon stimulated (isg)-15
# tnf-alpha interacts with il-1
# il-1 interacts with ifn-y
# vdr interacts with vdd1
# interleukin-2 interacts with icam-1
# c-myc interacts with egf-r
# dqb1 interacts with dr4
# adh1 interacts with adh2
# gk2 interacts with gk1
# cd22 interacts with cd7
# dr3 interacts with dqa1
# il-2 interacts with interleukin-6
# tumor necrosis factor alpha interacts with tumor necrosis factor-alpha
# tnf interacts with il-5
# d-ala-d interacts with pbg-d
# galactose-1-phosphate uridyltransferase interacts with gal-1-put
# interleukin-2, -3, -4, -6 interacts with proto-oncogene c-myc
# il-6 interacts with tumour necrosis factor
# tgf-beta interacts with p60
# hxb interacts with dyt1
# glucagon interacts with gh
# insulin interacts with prolactin
# tnf interacts with interferon-gamma
# prothrombin interacts with afp
# cd10 interacts with cd25
# il-1 interacts with cd11a
# insulin interacts with il-1
# alpha 1-antitrypsin interacts with c-reactive protein
# dopamine beta-hydroxylase interacts with tsc1
# hexb interacts with alpha- and a beta
# cnf interacts with lpl
# myc interacts with n-myc
# psti interacts with adh3
# nerve growth factor receptor interacts with chat
# nf1 interacts with neurofibromatosis type 1
# hla-b interacts with tnf beta
# igf-i interacts with her2
# vitamin d receptor interacts with ela1
# ifn-gamma interacts with interferon-gamma
# il-1 alpha interacts with tnf
# transforming growth factor-beta interacts with lymphocyte function-associated antigen 1
# tnf interacts with tumor necrosis factor (tnf)-alpha
# il-4 interacts with tnf
# c-myc interacts with myc
# tnf beta interacts with hla-drb1, -dqa1, -dqb1 and -dpb1
# alcohol dehydrogenase interacts with adh4
# il-1 beta interacts with gm-csf
# ifn-gamma interacts with ifn-y
# il-1 beta interacts with interleukin (il) 1 alpha
# arginosuccinate synthetase interacts with abl1
# neuropeptide y interacts with corticotropin releasing hormone
# fibrinogen interacts with viii
# hla-dqb1 interacts with hla
# neu interacts with pgr
# an2 interacts with acp1
# c-myc interacts with c-erbb-2
# cd4 interacts with cd10
# c-erbb-2 interacts with k-ras
# vasopressin interacts with cholecystokinin
# sd4 interacts with sd2
# cd22 interacts with cd5
# lamp1 interacts with lamp2
# tnf-alpha interacts with icam-1
# adh4 interacts with adh2
# vdr interacts with ela1
# apolipoproteins a-1 and b interacts with apolipoprotein a-i/b
# dr3 interacts with drb1
# arginosuccinate synthetase interacts with ass
# tumor necrosis factor alpha interacts with cachectin
# cd21 interacts with cd7
# il-4 interacts with il-5
# thyroglobulin interacts with mif
# ca ii interacts with oculocerebrorenal syndrome of lowe
# c-erbb-2 interacts with pgr
# glucose-6-phosphatase interacts with g6pase
# il-6 interacts with interleukin-1 alpha
# hla-b interacts with bat1
# tnf-alpha interacts with ige
# il-4 interacts with interferon-gamma
# methylmalonyl-coa mutase interacts with cbl b
# hla-drb1 interacts with hla-dqa1
# il-6 interacts with cd2
# drb1 interacts with dq2
# col7a1 interacts with collagen vii
# c4a and c4b interacts with c4b
# ifn-alpha 6 interacts with interferon regulatory factor 1
# adenylate kinase 1 interacts with dbh
# cd19 interacts with cd5
# icam-1 interacts with beta 1 integrins
# cytochrome oxidase subunit i interacts with nadh dehydrogenase subunit 6
# cd38 interacts with cd25
# interferon-alpha 4 interacts with alpha f1
# il-1 alpha interacts with ifn-y
# coi interacts with nadh dehydrogenase subunit 6
# cftr interacts with tau
# il-6 interacts with gm-csf
# il-6 interacts with interleukin (il) 1 alpha
# il-6 interacts with lfa-3
# interferon-alpha interacts with interferon-alpha 4
# abo blood group interacts with dbh
# abl interacts with abo
# il-1 beta interacts with ifn-alpha
# acid phosphatase-1 interacts with acp1
# sta interacts with hex a-)
# c3a interacts with c1inh
# tumor necrosis factor alpha interacts with tnf beta
# c-myc interacts with pgr
# hla-dqb1 interacts with dqb1
# irf-1 interacts with interferon regulatory factor 1
# dr3 interacts with dr4
# cftr interacts with mdr-1
# psti interacts with adh2
# cbl interacts with cbl b
# egfr interacts with transforming growth factor-alpha
# ifn-alpha interacts with alpha f1
# transforming growth factor beta 2 interacts with tgf-beta 1
# dr3 interacts with tsh-receptor
# igf-i interacts with insulin-like growth-factor-i receptors
# cbl interacts with cblc
# igg1 interacts with igg2b
# arylsulfatase a interacts with ars(b)
# l-myc interacts with n-myc
# interleukin-2 interacts with interleukin-6
# galactose-1-phosphate uridylyltransferase interacts with galactose-1-phosphate uridylyl-transferase
# ifn-alpha 4 interacts with ifn-alpha 6
# hxb interacts with ak1
# thyroglobulin interacts with tg
# psti interacts with formaldehyde dehydrogenase
# epidermal growth factor receptor interacts with interleukin-6
# hla interacts with hla-dqa1
# glucose-6-phosphatase interacts with g-6-pase
# cd4 interacts with fibrinogen
# il-2 interacts with interleukin 6
# erbb2 interacts with transforming growth factor-alpha
# cd4 interacts with cd22
# p107 interacts with nf-kappa b
# dqa1 interacts with dr5
# c4b interacts with dr1
# p53 interacts with rb-1
# porphobilinogen deaminase interacts with fch
# il-1 beta interacts with tnf alpha
# insulin interacts with avp
# interleukin-6 interacts with cd25
# ak1 interacts with xpa
# an2 interacts with wt1
# abl interacts with dopamine beta-hydroxylase
# hexb interacts with hexa
# interleukin-2 interacts with c-myc
# beta-endorphin interacts with igf-i and -ii
# igfbp-1 interacts with insulin-like growth factor-type i (igf-i
# il-6 interacts with ifn-alpha
# il-4 interacts with cd4
# interleukin-4 interacts with il-2
# il-1 interacts with interleukin 2
# ncf-47k interacts with p22-phox
# dbh interacts with tsc1
# tnf-alpha interacts with ifn-gamma
# gp91-phox interacts with p22-phox
# cln2 interacts with cdc34
# psa interacts with cap = 1
# cd4 interacts with cd2
# cd4 interacts with vla-1
# albumin interacts with antithrombin iii
# il-1 beta interacts with il-2-receptor
# progesterone receptor interacts with her2
# acetylcholinesterase interacts with cftr
# igf-ii interacts with rbp-1
# gelsolin interacts with ass
# ssl2 interacts with ercc-3
# transforming growth factor beta 2 interacts with tgf-beta 2
# vcam-1 interacts with beta 1 integrins
# interleukin-2 interacts with transforming growth factor-beta
# cd23 interacts with cd1
# epidermal growth factor receptor interacts with transforming growth factor-beta
# insulin-like growth factor-ii interacts with igf-i
# epidermal growth factor receptor interacts with tgf-alpha
# c-reactive protein interacts with renin
# il-6 interacts with tumor necrosis factor-alpha
# cystic fibrosis transmembrane conductance regulator interacts with c-met
# ki-ras interacts with n-ras
# il-6 interacts with tnf alpha
# p53 interacts with c-erbb-2
# tnf-alpha interacts with interleukin-6
# gm-csf interacts with tnf
# xpa interacts with tsc1
# interleukin-4 interacts with cdw32
# insulin interacts with dqa1
# galk interacts with galt
# tumor necrosis factor-alpha interacts with c-erb b-2
# interleukin-6 interacts with c-fms
# growth hormone interacts with gh
# interleukin 6 interacts with tumor necrosis factor-alpha
# ncf-47k interacts with gp91-phox
# il-6 interacts with interleukin 1
# alcohol dehydrogenase interacts with adh
# tnf alpha interacts with ifn gamma
# adh5 interacts with formaldehyde dehydrogenase
# drb1 interacts with tnf beta
# pgr interacts with egf-r
# anti-interleukin 2 receptor interacts with igg1
# adh4 interacts with fdh
# progesterone receptor interacts with egf-r
# k-ras interacts with dcc
# gsn interacts with dbh
# igf-ii interacts with igf-i
# il-2 interacts with tnf
# c-erbb-2 interacts with her-2/neu
# ifn-alpha 4 and -alpha 6 interacts with interferon stimulated (isg)-15
# il-6 interacts with il-2-receptor
# interleukin 6 interacts with interleukin 1
# p53 interacts with k-ras
# interleukin-2 interacts with il-4
# avp interacts with corticotropin releasing hormone
# tumor necrosis factor beta interacts with tsh-receptor
# cd8 interacts with cd10
# il-6 interacts with c-reactive protein
# alcohol dehydrogenase interacts with adh1
# ira1 interacts with ira2
# gm-csf interacts with il-5
# alpha 1-antitrypsin interacts with interleukin-6
# delta-aminolevulinic acid dehydratase interacts with pbg-d
# transforming growth factor-beta interacts with endothelial leukocyte adhesion molecule 1
# igfbp-1 interacts with igfbps
# hex a interacts with sta
# ssl2 interacts with his4
# tumour necrosis factor (tnf) alpha interacts with interleukin 6
# p22-phox interacts with p47-phox
# formaldehyde dehydrogenase interacts with adh3
# p53 interacts with pgr
# thyroglobulin interacts with tpo
# interleukin-1 interacts with c-erb b-2
# pc interacts with g6pase
# uroporphyrinogen i synthetase interacts with uro-s
# il-2-receptor interacts with ifn-y
# cartilage oligomeric matrix protein interacts with comp
# avp interacts with npy
# tumor necrosis factor-alpha interacts with cd11a
# cln1 interacts with cln2
# epidermal growth factor receptor interacts with erbb2
# cd25 interacts with cd1
# interleukin-6 interacts with hgf
# cftr interacts with cystic fibrosis transmembrane conductance regular
# pm-scl interacts with endothelial leukocyte adhesion molecule 1
# il-2 interacts with interferon gamma
# abl1 interacts with abo blood group
# insulin interacts with proinsulin
# interferon-alpha interacts with alpha f1
# il-2 interacts with il-5
# interleukin-2 interacts with intercellular adhesion molecule 1
# insulin-like growth factor i interacts with igf-i and -ii
# grp interacts with corticotropin releasing hormone
# hexa interacts with beta-hexosaminidase
# insulin interacts with drb1
# igf-i interacts with igfbp-1
# progesterone receptor interacts with insulin-like growth-factor-i receptors
# il-6 interacts with p53
# cd4 interacts with dqb1
# interleukin-4 interacts with ltk
# il-2 interacts with interferon-gamma
# beta hexosaminidase interacts with hex b
# cd10 interacts with cd1
# interleukin-2 interacts with interleukin-3
# interferon-gamma interacts with cd8
# igf-i interacts with insulin-like growth factor (igf)-i
# hla-b interacts with hla-dqa1
# ncf-47k interacts with p47-phox
# grp interacts with npy
# insulin interacts with vasopressin
# cftr interacts with gcl
# il-6 interacts with tumour necrosis factor (tnf) alpha
# hla-drb1 interacts with tnf-beta
# interferon-alpha 4 interacts with interferon stimulated (isg)-15
# c-myc interacts with interleukin-6
# arginosuccinate synthetase interacts with abo blood group
# gp91-phox interacts with p47-phox
# interleukin 6 interacts with interleukin 2
# gsn interacts with dyt1
# gastrin-releasing peptide interacts with corticotropin releasing hormone
# insulin-like growth factor-type i (igf-i interacts with igfbps
# ache interacts with cftr
# interleukin-4 interacts with proto-oncogene c-myc
# cd8 interacts with cd22
# ltk interacts with transforming growth factor beta
# alcohol dehydrogenase interacts with adh5
# hla-dqb1 interacts with dr5
# hla-drb1 interacts with iddm
# egfr interacts with k-ras
# insulin interacts with dr4
# p53 interacts with h-ras-1
# galk interacts with galactose-1-phosphate uridylyl-transferase
# insulin-like growth factor (igf)-i interacts with igfbp-1
# glucose-6-phosphatase interacts with phosphoenolpyruvate carboxykinase
# dqa1 interacts with hla-dqa1
# interleukin-6 interacts with interleukin-1
# cd4 interacts with cd23
# tnf alpha interacts with tsh-receptor
# gastrin-releasing peptide interacts with npy
# interleukin-6 interacts with transforming growth factor-beta
# dr3 interacts with hla
# ifn-gamma interacts with cd8
# cdw32 interacts with il-6
# cd2 interacts with cd19
# tnf-alpha interacts with interleukin 6
# formaldehyde dehydrogenase interacts with adh2
# insulin interacts with beta-endorphin
# igf-i-r interacts with her2
# neu interacts with progesterone receptor
# hla interacts with tnf-beta
# cd2 interacts with cd20
# acetylcholinesterase interacts with choline acetyltransferase
# interferon (ifn)-alpha interacts with ifn-alpha 2b
# il-1 alpha interacts with tnf-alpha
# tnf beta interacts with tsh-receptor
# pax-6 interacts with an2
# interferon-gamma interacts with c-fms
# viiivwf interacts with fab
# il-4 interacts with tnf-alpha
# bat1 interacts with bat2
# antithrombin iii interacts with afp
# il-6 interacts with il-2r
# il-2 interacts with cd4
# cd8 interacts with cd2
# interleukin-2 interacts with tnf
# transforming growth factor-alpha interacts with k-ras
# abl1 interacts with tsc1
# hla interacts with iddm
# gelsolin interacts with dyt1
# cd38 interacts with cd1
# psti interacts with adh4
# adh interacts with formaldehyde dehydrogenase
# cd2 interacts with cd30
# alpha 1-antitrypsin interacts with interleukin 6
# d-ala-d interacts with fch
# cbl b interacts with cbl a
# tumor necrosis factor alpha interacts with histocompatibility leucocyte antigens (hla)-b
# il-1 beta interacts with ifn-gamma
# at iii interacts with fibrinogen
# nerve growth factor interacts with igf-i and -ii
# rbp-2 interacts with p107
# arginosuccinate synthetase interacts with abl
# acetylcholinesterase interacts with chat
# cftr interacts with p-67
# c-myc interacts with progesterone receptor
# interleukin-4 interacts with lymphocyte function-associated antigen 1
# interleukin-2 interacts with cd2
# arginosuccinate synthetase interacts with tsc1
# an2 interacts with apob
# dqb1 interacts with hla-drb1, -dqa1, -dqb1 and -dpb1
# interleukin-3 interacts with interleukin-2, -3, -4, -6
# interleukin-2 interacts with c-erb b-2
# interleukin 1 (il-1 interacts with tumour necrosis factor
# corticotropin releasing hormone interacts with acth
# epidermal growth factor receptor interacts with c-erb b-2
# p53 interacts with her-2/neu
# hla-a interacts with psti
# cd30 interacts with cd1
# il-6 interacts with gp130
# interleukin-2 interacts with interferon-gamma
# cd20 interacts with cd30
# il-1 beta interacts with alpha 1 protease inhibitor
# epidermal growth factor receptor interacts with interferon-gamma
# pick interacts with gp91-phox
# interleukin-6 interacts with il-6r
# il-1 beta interacts with interleukin-6
# alpha-2 interacts with transferrin
# interleukin-6 interacts with tcii
# nerve-growth-factor interacts with nerve-growth factor
# grp interacts with acth
# thyroglobulin interacts with tsh receptor
# interleukin-6 interacts with interleukin-2, -3, -4, -6
# gsn interacts with ak1
# cd2 interacts with cd38
# abo interacts with tsc1
# uroporphyrinogen-1-synthetase interacts with cytochrome p-450
# tnf-alpha interacts with tnf
# il-6 interacts with ifn-gamma
# pbg-d interacts with ferrochelatase
# hla-b interacts with bat2
# ifn-alpha interacts with ifn-alpha 4 and -alpha 6
# il-1 alpha interacts with interleukin-1 beta
# acetylcholinesterase interacts with nerve growth factor receptor
# egf-r interacts with her2
# p53 interacts with interleukin-6
# transforming growth factor beta 2 interacts with tgf-beta 3
# il-2-receptor interacts with il-1
# tnf-alpha interacts with tgf-beta
# cftr interacts with cf transmembrane conductance regulator
# cd21 interacts with cd22
# his4 interacts with ssl1
# cd4 interacts with il-2r
# growth hormone interacts with igf-binding protein-1
# tumor necrosis factor alpha interacts with tumor necrosis factor beta
# ar interacts with psti
# c-erbb-2 interacts with estrogen/progesterone receptors
# il-1 interacts with interleukin-1
# vitamin d receptor interacts with col2a1
# alpha-1-antitrypsin interacts with c-reactive protein
# il-1 alpha interacts with il-6
# migration inhibition factor interacts with mif
# gastrin-releasing peptide interacts with acth
# ak1 interacts with dbh
# nerve growth factor interacts with insulin-like growth factor i
# il-4 interacts with il-6
# c-myc interacts with interleukin-3
# vasopressin interacts with acth
# cd8 interacts with cd20
# cftr interacts with cystic fibrosis (cf) transmembrane conductance regulator
# interferon-gamma interacts with interleukin-1
# c-myc interacts with n-myc
# anti-interleukin 2 receptor interacts with igg2b
# transforming growth factor beta 1 interacts with p60
# rbp-2 interacts with beta-endorphin
# interferon-gamma interacts with transforming growth factor-beta
# galactokinase interacts with galt
# cd23 interacts with cd71
# transforming growth factor beta 1 interacts with p60/p105/
# delta-aminolevulinic acid dehydratase interacts with d-ala-d
# serum albumin interacts with sta
# abl interacts with abo blood group
# adrenocorticotropic hormone interacts with prolactin
# il-6 interacts with ril-2
# neurofibromatosis type 1 interacts with ira1
# ercc1 interacts with ercc2
# il-6 interacts with interleukin 1 (il-1
# il-1 interacts with cd11b
# il-6 interacts with nf-il6
# tnf-alpha interacts with interferon-gamma
# crp interacts with renin
# insulin interacts with crh
# pm-scl interacts with intercellular adhesion molecule 1
# ifn-alpha 6 interacts with alpha f1
# grp interacts with neuropeptide y
# c4b interacts with hla-a, b, c) of class ii
# gelsolin interacts with ak1
# il-2 interacts with il-1
# growth hormone interacts with ghrh
# nerve growth factor interacts with glucagon
# drb1 interacts with hla-dqa1
# vdr interacts with col2a1
# il-6 interacts with c-fos
# tgf-beta 1 interacts with p60/p105/
# interleukin-2 receptor interacts with il-2r
# tgf-beta interacts with transforming growth factor-beta
# fibrinogen interacts with prothrombin
# il-4 interacts with tumor necrosis factor
# pc interacts with phosphoenolpyruvate carboxykinase
# interleukin-1 alpha interacts with ifn-alpha
# vasopressin interacts with crh
# cd4 interacts with cd8
# formaldehyde dehydrogenase interacts with fdh
# cd4 interacts with cd25
# tnf-alpha interacts with ifn-y
# hla-dqb1 interacts with hla-dqa1
# tnf-alpha interacts with vascular cell adhesion molecule-1
# crh interacts with acth
# uro-s interacts with cytochrome p-450
# dr3 interacts with tnf beta
# nerve growth factor interacts with ngf
# interleukin-2 interacts with epidermal growth factor receptor
# hxb interacts with abl1
# amyloid precursor protein interacts with beta amyloid precursor protein
# npy interacts with crh
# gelsolin interacts with tsc1
# gastrin-releasing peptide interacts with neuropeptide y
# tnf-alpha interacts with cd11a
# alpha 1-antitrypsin interacts with factor xa
# cd2 interacts with cd7
# vasopressin interacts with neuropeptide y
# ncam interacts with stmy
# vitamin d receptor interacts with pddr
# interleukin-2 interacts with hla-dqb1
# tnf interacts with tsh-receptor
# interleukin-6 interacts with cd2
# transforming growth factor-alpha interacts with her-2/neu
# interleukin 6 interacts with hgf
# hxb interacts with ass
# cd25 interacts with cd71
# p53 interacts with progesterone receptor
# hex a and b interacts with hex
# il-6 interacts with renin
# interleukin-2 interacts with interleukin-2 receptor
# cd10 interacts with cd23
# insulin interacts with hla
# dqb1 interacts with dqb
# cd22 interacts with cd30
# psti interacts with adh
# cd19 interacts with cd20
# interleukin-4 interacts with icam-1
# hlyb interacts with ste6
# hxb interacts with gelsolin
# hxb interacts with arginosuccinate synthetase
# interleukin-6 interacts with lfa-3
# p53 interacts with all 3
# il-2 interacts with tnf-alpha
# cd10 interacts with cd21
# ngf receptor interacts with choline acetyltransferase
# p107 interacts with p300
# alpha-2-macroglobulin interacts with transferrin
# thyroglobulin interacts with cd4
# androgen receptor interacts with ta
# il-1 beta interacts with interleukin 6
# insulin interacts with gh
# interleukin-4 interacts with il-1 alpha
# dqa1 interacts with iddm
# crp interacts with a1at
# cd10 interacts with cd71
# antithrombin iii interacts with crp
# psti interacts with adh1
# epidermal growth factor receptor interacts with egfr
# interferon-gamma interacts with interleukin-2, -3, -4, -6
# ifn-alpha interacts with il-1
# hxb interacts with adenylate kinase 1
# insulin-like growth-factor-i receptors interacts with her2
# cd20 interacts with cd7
# interleukin-1 alpha interacts with il-2-receptor
# vdr interacts with pddr
# estrogen receptor interacts with neu
# tp53 interacts with mycn
# igf-i interacts with insulin-like growth factor-type i (igf-i
# cathepsin b interacts with cat b
# cd19 interacts with cd30
# transforming growth factor-alpha interacts with interleukin-6
# cd4 interacts with ril-2
# ltk interacts with il-6
# dyt1 interacts with tsc1
# fdh interacts with adh3
# p53 interacts with interleukin 6
# carbonic anhydrase ii interacts with ca ii
# tumor necrosis factor-alpha interacts with c-fms
# tnf interacts with tcii
# c-myc interacts with interferon-gamma
# beta 2 interacts with beta 1 integrins
# galactokinase interacts with galactose-1-phosphate uridylyl-transferase
# tnf-beta interacts with tumor necrosis factor (tnf)-alpha
# tgf-beta 1 interacts with tgf-beta 3
# ocrl interacts with oculocerebrorenal syndrome of lowe
# gastrin-releasing peptide interacts with bradykinin
# cdc28 interacts with cdc34
# interferon-alpha interacts with ifn-alpha 4 and -alpha 6
# ngf receptor interacts with chat
# vascular cell adhesion molecule-1 interacts with beta 1 integrins
# abl1 interacts with abo
# il-1 interacts with interleukin (il)-1
# succinate dehydrogenase interacts with sdh
# galactokinase interacts with gal1
# cd25 interacts with cd7
# tnf alpha interacts with tumor necrosis factor-alpha
# interleukin-4 interacts with endothelial leukocyte adhesion molecule 1
# cd23 interacts with cd5
# icam-1 interacts with lymphocyte function-associated antigen 1
# insulin-like growth factor (igf)-i interacts with insulin-like growth factor-type i (igf-i
# cftr interacts with pkg
# sphingolipid activator protein 1 interacts with sap-1
# pax-6 interacts with wt1
# dqa1 interacts with dq2
# cytochrome oxidase subunit i interacts with coi
# delta-aminolevulinic acid dehydratase interacts with fch
# tumor necrosis factor beta interacts with tnf beta
# cd4 interacts with igg2b
# p53 interacts with estrogen/progesterone receptors
# interleukin-6 interacts with lymphocyte function-associated antigen 1
# cd19 interacts with cd38
# retinoblastoma gene product (p105) interacts with p60/p105/
# transforming growth factor-beta interacts with pm-scl
# arginosuccinate synthetase interacts with abo
# int-3 interacts with cdc-10
# igf-ii interacts with beta-endorphin
# adh5 interacts with adh
# il-6 interacts with c reactive protein
# psti interacts with adh5
# nf1 interacts with ira1
# pyruvate carboxylase interacts with g6pase
# neu interacts with egf-r
# abl1 interacts with dopamine beta-hydroxylase
# interleukin 2 receptor interacts with iga-aga
# albumin interacts with crp
# interleukin-6 interacts with tumor necrosis factor-alpha
# dqb1 interacts with dr1
# il-1 beta interacts with tnf
# interleukin-4 interacts with ifn-gamma
# dqb1 interacts with drb1
# interleukin 6 interacts with c reactive protein
# c-myc interacts with her2
# adh5 interacts with adh1
# alpha-1 interacts with alpha-2
# il-2 interacts with il-6
# neurofibromatosis type 1 interacts with ira2
# hla-drb1 interacts with dqa1
# il-1 beta interacts with ril-1 beta
# dr3 interacts with dqb
# tcii interacts with tci and iii
# antithrombin iii interacts with factor xa
# alpha 1-antitrypsin interacts with alpha 1-at
# ngf interacts with ache
# neu interacts with igf-i
# interleukin-6 interacts with interleukin 1
# progesterone receptor interacts with erbb2
# 5-aminolevulinate synthase interacts with glycophorin a
# tnf interacts with rtnf
# fdh interacts with adh2
# retinoblastoma interacts with nf 1
# rbp-1 interacts with rbp-2
# k-ras interacts with n-ras
# hex a interacts with hexa
# cd4 interacts with il-1 beta
# cd8 interacts with cd25
# arginosuccinate synthetase interacts with dopamine beta-hydroxylase
# transferrin interacts with hemopexin
# gk2 interacts with gal1
# interleukin-4 interacts with interleukin-6
# cd30 interacts with cd71
# nerve growth factor interacts with igf-ii
# cat l interacts with cathepsin d
# apoai interacts with stmy
# interleukin-6 interacts with c-reactive protein
# abl interacts with xpa
# il-1 beta interacts with il-5
# adenylate kinase 1 interacts with ass
# insulin interacts with nerve growth factor
# cystic fibrosis transmembrane conductance regulator interacts with cystic fibrosis conductance transmembrane regulator
# interleukin-1 beta interacts with interleukin-6
# il-2 interacts with tumor necrosis factor
# pax6 interacts with pax-6
# cln3 interacts with cdc34
# interleukin 6 interacts with tcii
# cd10 interacts with cd5
# neu interacts with insulin-like growth-factor-i receptors
# alpha f1 interacts with ifn-alpha 4 and -alpha 6
# antithrombin iii interacts with thrombin
# nerve growth factor interacts with ache
# rbp-1 interacts with p107
# il-1 beta interacts with interferon-gamma
# tumor necrosis factor alpha interacts with tnf alpha
# tumor necrosis factor-alpha interacts with transforming growth factor-beta
# sta interacts with hex a- and hex b-)
# rb1 interacts with mycn
# tumor necrosis factor interacts with tnf alpha
# tnf alpha interacts with tumour necrosis factor (tnf) alpha
# antithrombin iii interacts with viii
# irf-1 interacts with interferon stimulated (isg)-15
# il-6 interacts with tgf-beta
# abo interacts with dopamine beta-hydroxylase
# pax-3 interacts with pax
# il-6 interacts with ril-1 beta
# interleukin-2 interacts with cd8
# adh1 interacts with formaldehyde dehydrogenase
# ifn-gamma interacts with interleukin-1 alpha
# c-myc interacts with igf-i
# interleukin-2 interacts with cd25
# hla-dqb1 interacts with tnf-beta
# il-1 beta interacts with ifn-y
# p53 interacts with c-erb b-2
# gastrin-releasing peptide interacts with bombesin
# tnf alpha interacts with tnf beta
# b18 interacts with sco1
# dqb1 interacts with hla-dpb1
# ass interacts with dyt1
# interleukin 6 interacts with tumour necrosis factor
# glucose-6-phosphatase interacts with pepck
# antithrombin iii interacts with alpha 1-antitrypsin
# apolipoproteins a-1 and b interacts with apolipoprotein a-i
# er interacts with pgr
# drb1 interacts with iddm
# cd19 interacts with cd7
# p53 interacts with interferon-gamma
# ifn-gamma interacts with gm-csf
# methylmalonyl-coa mutase interacts with cbl a
# tumor necrosis factor-alpha interacts with cd11b
# c1-inhibitor interacts with c1inh
# insulin interacts with igf-i and -ii
# il-1 beta interacts with cd11a
# il-6 interacts with il-5
# c-myc interacts with insulin-like growth-factor-i receptors
# interleukin-1 interacts with transforming growth factor-beta
# transferrin interacts with haptoglobin
# haptoglobin interacts with ceruloplasmin
# il-4 interacts with ltk
# cftr interacts with cystic fibrosis transmembrane conductance regulator
# cbl interacts with cbl a
# interleukin-6 interacts with tci and iii
# tumor necrosis factor alpha interacts with il-1
# iga interacts with iga-aga
# igf-i interacts with igf-i-r
# alpha- and beta-glucosidase interacts with beta mannosidase
# ifn-alpha interacts with ifn-alpha 4
# c3, c4 interacts with c3, c4, factor b
# il-1 alpha interacts with interleukin-1 alpha
# hla-drb1 interacts with tumor necrosis factor-beta
# hxb interacts with abo blood group
# dr4 interacts with dqb
# erbb2 interacts with tp53
# interleukin-1 interacts with cd11b
# cd4 interacts with cd1
# il-1 interacts with tumor necrosis factor-alpha
# gla interacts with mlc
# hla-drb1 interacts with dr4
# interleukin-2 interacts with c-fms
# dr3 interacts with hla-dqa1
# cdw32 interacts with transforming growth factor beta
# cd38 interacts with cd5
# histocompatibility leucocyte antigens (hla)-b interacts with tsh-receptor
# epidermal growth factor receptor interacts with c-fms
# rbp-1 interacts with beta-endorphin
# igg2a interacts with igg2b
# adh4 interacts with formaldehyde dehydrogenase
# interferon-gamma interacts with tumor necrosis factor-alpha
# interleukin-2 interacts with il-6
# ifn-gamma interacts with ifn-alpha
# ltk interacts with cdw32
# iga interacts with cd4
# albumin interacts with viii
# il-1 interacts with interleukin 1
# ngf interacts with acetylcholinesterase
# adh interacts with adh1
# cftr interacts with acylcholine acylhydrolase
# interleukin-6 interacts with il-2r
# antithrombin iii interacts with alpha 1-at
# interleukin-1 alpha interacts with alpha 1 protease inhibitor
# p53 interacts with nf-1
# gelsolin interacts with dopamine beta-hydroxylase
# hla-dqb1 interacts with lymphocyte function-associated antigen 1
# alpha1 leads to 2) gal (beta1 leads to 4) glcnac(beta1 interacts with beta1
# cd21 interacts with cd25
# tgf-beta interacts with tumor necrosis factor-alpha
# ifn-alpha 6 interacts with ifn-alpha 4 and -alpha 6
# hla interacts with tumor necrosis factor-beta
# alpha-2 interacts with alpha-2-macroglobulin
# drd2 interacts with d2 dopamine receptor
# gsn interacts with abl1
# cd30 interacts with cd5
# arginosuccinate synthetase interacts with dbh
# hla interacts with dr4
# hla-drb1, -dqa1, -dqb1 and -dpb1 interacts with hla-dpb1
# cd2 interacts with cd10
# alpha n-catenin interacts with beta-catenin
# glucagon interacts with growth hormone
# icam-1 interacts with endothelial leukocyte adhesion molecule 1
# growth hormone interacts with igf-2
# alpha-1-antitrypsin interacts with a1at
# bombesin interacts with bradykinin
# il-6 interacts with cd4
# nerve growth factor interacts with acetylcholinesterase
# dopamine beta-hydroxylase interacts with xpa
# gsn interacts with ass
# ta interacts with tabby
# apolipoprotein b interacts with apolipoprotein a-i/b
# hex a interacts with hex a-)
# gfap interacts with interleukin 2
# serum albumin interacts with hex a
# interleukin-4 interacts with interleukin-3
# beta-galactosidase interacts with neuraminidase
# estrogen receptor interacts with c-erbb-2
# cftr interacts with c-met
# transforming growth factor-alpha interacts with c-erb b-2
# tnf-alpha interacts with interleukin-1 beta
# gsn interacts with arginosuccinate synthetase
# tumor necrosis factor-alpha interacts with interleukin (il)-1
# androgen receptor interacts with tabby
# cftr interacts with ttr
# haptoglobin interacts with hemopexin
# fibrinogen interacts with c-reactive protein
# dr3 interacts with tumor necrosis factor beta
# hxb interacts with abl
# interleukin-6 interacts with gp130
# transforming growth factor-alpha interacts with interferon-gamma
# ki-ras interacts with gas-3
# ifn-gamma interacts with il-2-receptor
# ass interacts with abl
# hxb interacts with tsc1
# vcam-1 interacts with icam-1
# gsn interacts with adenylate kinase 1
# adenylate kinase 1 interacts with dyt1
# tnf alpha interacts with alpha 1 protease inhibitor
# ass interacts with tsc1
# cbld interacts with methionine synthase
# interleukin-6 interacts with her-2/neu
# bradykinin interacts with cholecystokinin
# gelsolin interacts with abl1
# vitamin d receptor interacts with vdr
# dr4 interacts with dr1
# cmt 1 interacts with cmt 2
# abo blood group interacts with dyt1
# p53 interacts with retinoblastoma (rb)
# neuropeptide y interacts with crh
# drb1 interacts with hla-drb1, -dqa1, -dqb1 and -dpb1
# insulin interacts with il-6
# pgr interacts with her2
# pyruvate carboxylase interacts with phosphoenolpyruvate carboxykinase
# glucagon interacts with igf-i and -ii
# igf-i interacts with igf-i and -ii
# iga interacts with interleukin 2 receptor
# alpha 1-antitrypsin interacts with a-1--at
# interleukin-1 interacts with interleukin (il)-1
# c-myc interacts with cd25
# gm-csf interacts with fibrinogen
# alpha-2 interacts with haptoglobin
# interleukin-2 interacts with interleukin-1
# pc interacts with pepck
# ferrochelatase interacts with fch
# cd4 interacts with gm-csf
# galactokinase interacts with gal-1
# ifn-alpha 4 interacts with interferon stimulated (isg)-15
# epidermal growth factor receptor interacts with interleukin-1
# tnf-alpha interacts with tumor necrosis factor
# transforming growth factor beta 1 interacts with retinoblastoma gene product (p105)
# ...
# tnf beta interacts with hla-dpb1
# dr3 interacts with dq2
# hla-a interacts with hla-b
# ifn-alpha interacts with ifn-y
# hla interacts with hla-drb1
# p53 interacts with tumor-suppressor
# galactokinase interacts with galactose-1-phosphate uridyltransferase
# cd21 interacts with cd1
# vitamin d receptor interacts with parathyroid hormone
# ncf-1 interacts with ncf-47k
# arylsulfatase a interacts with ars(a)
# cd2 interacts with interleukin-2 receptor
# interleukin-6 interacts with c reactive protein
# cd4 interacts with igg1
# interleukin-4 interacts with hla-dqb1
# cd23 interacts with cd30
# dr3 interacts with dqb1
# cftr interacts with alpha 1-antitrypsin
# tumor necrosis factor-alpha interacts with cachectin
# il-4 interacts with cd8
# interleukin-6 interacts with matrix metalloproteinase 1
# dqb1 interacts with tnf beta
# tnf interacts with interleukin 1 (il-1
# hla-dqb1 interacts with interleukin-6
# oat interacts with cyp2e-1
# hxb interacts with abo
# dr3 interacts with tnf alpha
# cd19 interacts with cd22
# alpha-1-antitrypsin interacts with antithrombin iii
# il-2 interacts with transforming growth factor beta
# c-erbb-2 interacts with erbb2
# c4b interacts with hla-a, b, c
# ass interacts with abo
# il-1 beta interacts with tumor necrosis factor
# tnf-alpha interacts with interleukin (il)-1
# il-2 interacts with interleukin-2 receptor
# il-6 interacts with interleukin-1 beta
# cd71 interacts with cd1
# interleukin-2 interacts with lfa-3
# interleukin-2 interacts with proto-oncogene c-myc
# p-glycoprotein interacts with mdr1
# p300 interacts with nf-kappa b
# cd4 interacts with cd7
# p-glycoprotein interacts with cystic-fibrosis transmembrane-conductance regulator
# hla-b interacts with tnf
# insulin interacts with dr3
# igf-ii interacts with igfbp-1
# her-2/neu interacts with c-erb b-2
# tnf-alpha interacts with fibrinogen
# interferon-alpha 4 interacts with ifn-alpha 4 and -alpha 6
# tgf-beta interacts with tgf-beta 1
# cd4 interacts with icam-1
# gelsolin interacts with abo blood group
# insulin-like growth factor i interacts with rbp-2
# cd20 interacts with cd23
# c-myc interacts with neu
# igf-ii interacts with insulin-like growth factor (igf)-i
# cd10 interacts with cd19
# antithrombin iii interacts with at iii
# ncf-1 interacts with p22-phox
# dopamine beta-hydroxylase interacts with dbh
# alpha-1-antitrypsin interacts with alpha1-antitrypsin
# thyroglobulin interacts with migration inhibition factor
# cbl c interacts with cbl a
# cd23 interacts with cd38
# hxb interacts with dopamine beta-hydroxylase
# cd10 interacts with cd20
# antithrombin iii interacts with prothrombin
# cd25 interacts with cd30
# insulin-like growth factor i interacts with p107
# gsn interacts with abl
# ass interacts with dopamine beta-hydroxylase
# insulin interacts with acth
# g-csf interacts with interleukin-2
# p53 interacts with p21
# c-reactive protein interacts with viii
# gsn interacts with tsc1
# galactose-1-phosphate uridylyl-transferase interacts with galt
# insulin interacts with leukocyte antigen (hla) dqa1
# hex a interacts with hex b
# c-myc interacts with interleukin-2, -3, -4, -6
# galactose-1-phosphate uridylyltransferase interacts with galk
# transforming growth factor-beta interacts with intercellular adhesion molecule 1
# il-6 interacts with interleukin-6
# tnf-alpha interacts with interleukin-1 alpha
# insulin interacts with igf-2
# p53 interacts with c-myc
# il-2 interacts with interleukin 2
# cd10 interacts with cd30
# interleukin 6 interacts with il6
# dqb1 interacts with dr5
# alpha and beta globin interacts with glycophorin a
# estrogen receptor interacts with progesterone receptor
# abl1 interacts with xpa
# drb1 interacts with dr4
# il-1 beta interacts with interleukin-1
# hla-drb1 interacts with hla-drb1, -dqa1, -dqb1 and -dpb1
# egf-r interacts with igf-i-r
# hex a-) interacts with hex a- and hex b-)
# ttr interacts with transthyretin
# interferon gamma interacts with ifn gamma
# hla-dqb1 interacts with tumor necrosis factor-beta
# cd4 interacts with cd5
# glucagon interacts with igf-ii
# npy interacts with acth
# p53 interacts with rb1
# growth hormone interacts with igf-1
# cd4 interacts with endothelial leukocyte adhesion molecule 1
# hla-dqb1 interacts with dr4
# hla-b interacts with tumor necrosis factor (tnf)-alpha
# interleukin-2 interacts with lymphocyte function-associated antigen 1
# tgf-beta 1 interacts with p60
# d2 dopamine receptor interacts with ncam
# tnf interacts with histocompatibility leucocyte antigens (hla)-b
# adh4 interacts with adh
# alpha- and beta-glucosidase interacts with alpha- and beta-galactosidase
# androgen receptor interacts with sbma
# tgf-beta interacts with tgf-beta 2
# retinol-binding protein interacts with rbp
# interleukin 6 interacts with interleukin 1 (il-1
# icam-1 interacts with vascular cell adhesion molecule-1
# tnf-alpha interacts with beta 2
# tumor necrosis factor alpha interacts with tnf
# pax-3 interacts with splotch
# interferon regulatory factor 1 interacts with interferon stimulated (isg)-15
# mig interacts with hla-b27
# tumor necrosis factor interacts with tnf
# cd8 interacts with cd23
# p53 interacts with interleukin-1
# il-1 beta interacts with cd11b
# cdw32 interacts with il-2
# gm-csf interacts with il-3
# interleukin 6 interacts with c-fos
# irf-1 interacts with alpha f1
# interleukin-2 interacts with tumor necrosis factor-alpha
# il-2r interacts with igg1
# intercellular adhesion molecule 1 interacts with lymphocyte function-associated antigen 1
# p53 interacts with transforming growth factor-beta
# arginosuccinate synthetase interacts with xpa
# dopamine beta-hydroxylase interacts with dyt1
# glucose-6-phosphatase interacts with pc
# gelsolin interacts with abl
# icam-1 interacts with pm-scl
# epidermal growth factor receptor interacts with tumor necrosis factor-alpha
# p53 interacts with tgf-alpha
# adh4 interacts with adh1
# methylmalonyl-coa mutase interacts with cbl
# cd8 interacts with cd21
# insulin interacts with neuropeptide y
# il-1 interacts with matrix metalloproteinase 1
# fibrinogen interacts with a1at
# interferon-alpha interacts with interferon regulatory factor 1
# cystic fibrosis transmembrane conductance regulator interacts with calcium/calmodulin-dependent protein kinase i
# hla interacts with hla-drb1, -dqa1, -dqb1 and -dpb1
# interleukin-3 interacts with proto-oncogene c-myc
# ass interacts with abl1
# 5-aminolevulinate synthase interacts with alpha and beta globin
# interleukin-6 interacts with pm-scl
# hla-drb1 interacts with sco1
# cd10 interacts with cd38
# cd4 interacts with ifn-gamma
# interleukin-4 interacts with tnf-alpha
# insulin-like growth factor i interacts with beta-endorphin
# ak1 interacts with dyt1
# cd1 interacts with cd5
# cbl interacts with cbld
# il-6 interacts with transforming growth factor-beta
# il-2 interacts with il-2r
# nerve growth factor interacts with rbp-2
# hla-b interacts with hla-drb1
# il-2 interacts with il-3
# hla-dqb1 interacts with intercellular adhesion molecule 1
# interleukin-1 alpha interacts with tnf alpha
# estrogen receptor interacts with igf-ii
# cd23 interacts with cd7
# c-erb b-2 interacts with c-fms
# abo interacts with xpa
# interleukin 2 interacts with glial fibrillary acidic protein
# tumor necrosis factor interacts with il-5
# tgf-beta 2 interacts with tgf-beta 3
# carbonic anhydrase ii interacts with oculocerebrorenal syndrome of lowe
# interleukin-6 interacts with proto-oncogene c-myc
# lp(a) interacts with apolipoproteins a-1 and b
# c3a interacts with c1-inhibitor
# ret interacts with ptc-1
# cd22 interacts with cd23
# glucagon interacts with transthyretin
# nerve growth factor interacts with p107
# cd2 interacts with cd25
# acetylcholinesterase interacts with ache
# cd4 interacts with interleukin-6
# coagulation factor x interacts with thrombin
# c3, c3, c4, c3-proactivator interacts with alpha 1, alpha 2
# il-1 alpha interacts with il-1 beta
# tnf interacts with tumor necrosis factor beta
# interleukin 2 interacts with tumour necrosis factor
# il-4 interacts with il-1 beta
# k-ras interacts with her-2/neu
# ncf-1 interacts with p47-phox
# epidermal growth factor receptor interacts with k-ras
# ocrl interacts with ca ii
# c-myc interacts with dcc
# cdc28 interacts with cln2
# p53 interacts with erbb2
# choline acetyltransferase interacts with chat
# il-1 interacts with tumour necrosis factor
# pyruvate carboxylase interacts with pepck
# somatotropin interacts with igf-binding protein-1
# hxb interacts with dbh
# tnf-alpha interacts with tumor necrosis factor-alpha
# cftr interacts with mdr1
# il-2 interacts with cd8
# c-myc interacts with proto-oncogene c-myc
# hla-b interacts with hla-dqb1
# interleukin-2 interacts with p53
# albumin interacts with transferrin
# transforming growth factor-beta interacts with c-erb b-2
# adh4 interacts with adh5
# insulin interacts with dqb1
# interleukin-1 alpha interacts with il-1
# vasopressin interacts with bradykinin
# hla-dqa1 interacts with tumor necrosis factor-beta
# vcam-1 interacts with vascular cell adhesion molecule-1
# alcohol dehydrogenase interacts with fdh
# egfr interacts with tgf-alpha
# adenylate kinase 1 interacts with dopamine beta-hydroxylase
# antithrombin iii interacts with fibrinogen
# tnf-alpha interacts with interleukin 1
# neu interacts with her2
# insulin-like growth-factor-i receptors interacts with igf-i-r
# hxb interacts with gsn
# cd20 interacts with cd25
# il-6 interacts with interleukin 6
# cdc28 interacts with cln1
# igg1 interacts with igg2a
# tnf interacts with tumour necrosis factor
# rb1 interacts with tp53
# abo blood group interacts with dopamine beta-hydroxylase
# igf-1 interacts with igf-2
# interleukin (il)-1 interacts with cd11a
# il-6 interacts with il-6r
# notch interacts with cdc-10
# cystic fibrosis transmembrane conductance regulator interacts with pkg
# cat b interacts with cathepsin d
# il-1 beta interacts with interleukin (il)-1
# vitamin d receptor interacts with vitamin d3 receptor
# cd10 interacts with cd7
# retinoblastoma gene product (p105) interacts with p60
# cd8 interacts with il-2r
# interleukin-1 interacts with c-fms
# l-selectin interacts with vla-1
# hla-a, b, c interacts with dr1
# il-4 interacts with il-2
# cd21 interacts with cd23
# gelsolin interacts with xpa
# transforming growth factor-alpha interacts with interleukin-1
# ars(b) interacts with mitochondrial aconitase
# il-1 beta interacts with fibrinogen
# transforming growth factor-alpha interacts with transforming growth factor-beta
# interleukin-4 interacts with il-6
# ptc-1 interacts with ptc-2
# transforming growth factor-alpha interacts with tgf-alpha
# cd38 interacts with cd71
# nerve growth factor interacts with beta-endorphin
# apolipoprotein a-i interacts with apolipoprotein a-i/b
# tnf-alpha interacts with tumor necrosis factor alpha
# e-cadherin interacts with beta-catenin
# il-6 interacts with crp
# hfe interacts with hla-b, -c, -e, (-a, -h, -g), and -f
# tnf-alpha interacts with cachectin
# cd21 interacts with cd71
# c-erbb-2 interacts with epidermal growth factor receptor
# cftr interacts with bche
# igf-i interacts with igfbps
# dqb1 interacts with hla-dqa1
# tgf-beta interacts with p60/p105/
# cd8 interacts with cd5
# dbh interacts with dyt1
# il-2 interacts with interleukin 1 (il-1
# galactose-1-phosphate uridylyltransferase interacts with galt
# egfr interacts with erbb2
# gm-csf interacts with tumor necrosis factor
# interleukin-2 interacts with il-2r
# cftr interacts with sucrase-isomaltase
# insulin interacts with growth hormone
# insulin interacts with gastrin-releasing peptide
# cln3 interacts with cln2
# adenylate kinase 1 interacts with abl1
# cbl interacts with cble
# il-4 interacts with cdw32
# ak1 interacts with abl
# p53 interacts with transforming growth factor-alpha
# il-1 beta interacts with interleukin-1 alpha
# hla-b interacts with hla-drb1, -dqa1, -dqb1 and -dpb1
# ak1 interacts with tsc1
# albumin interacts with fibrinogen
# c-myc interacts with igf-i-r
# il-6 interacts with fibrinogen
# androgen receptor interacts with ar
# interferon-gamma interacts with proto-oncogene c-myc
# ifn-alpha 4 interacts with alpha f1
# d-ala-d interacts with porphobilinogen deaminase
# gsn interacts with abo
# glucagon interacts with rbp-1
# igf-i interacts with rbp-1
# xpa interacts with dyt1
# pkg interacts with calcium/calmodulin-dependent protein kinase i
# p53 interacts with hsp70
# il-2 interacts with ifn gamma
# il-6 interacts with tnf
# cbld interacts with cble
# estrogen/progesterone receptors interacts with pgr
# progesterone receptor interacts with tp53
# insulin-like growth factor (igf)-i interacts with igfbps
# dr4 interacts with dr5
# hla interacts with dqa1
# adenylate kinase 1 interacts with arginosuccinate synthetase
# hla-dqb1 interacts with pm-scl
# cln3 interacts with cln1
# interleukin-2 interacts with endothelial leukocyte adhesion molecule 1
# pm-scl interacts with lymphocyte function-associated antigen 1
# c-erbb-2 interacts with egfr
# cd4 interacts with intercellular adhesion molecule 1
# interleukin-4 interacts with c-myc
# gastrin-releasing peptide interacts with cholecystokinin
# tnf interacts with interleukin (il) 1 alpha
# cd38 interacts with cd7
# igf-ii interacts with insulin-like growth factor-type i (igf-i
# gal1 interacts with gk1
# p53 interacts with dcc
# pbg-d interacts with fch
# igf-i interacts with egf-r
# intercellular adhesion molecule 1 interacts with endothelial leukocyte adhesion molecule 1
# neuropeptide y interacts with npy
# vasopressin interacts with bombesin
# ars(a) interacts with mitochondrial aconitase
# cytochrome oxidase subunit i interacts with nd6
# col2a1 interacts with collagen alpha 1(ii) chain
# bradykinin interacts with neurotensin
# hex a interacts with hex a- and hex b-)
# coi interacts with nd6
# hla-drb1 interacts with drb1
# cd22 interacts with cd25
# il-6 interacts with interferon gamma
# 5-aminolevulinate synthase interacts with alas
# interleukin-2 interacts with her-2/neu
# glucagon interacts with igf-i
# thyroglobulin interacts with serum albumin
# c-myc interacts with k-ras
# epidermal growth factor receptor interacts with her-2/neu
# gsn interacts with dopamine beta-hydroxylase
# cbl b interacts with cbl c
# growth hormone interacts with growth hormone-releasing hormone
# crp interacts with viii
# pax-6 interacts with pax-3
# interleukin-2 interacts with ifn-gamma
# hla-dqb1 interacts with hla-drb1
# interferon-alpha 4 interacts with ifn-alpha 4
# galactokinase interacts with galactose-1-phosphate uridylyltransferase
# galactose-1-phosphate uridyltransferase interacts with gal-1
# tnf-alpha interacts with beta 1 integrins
# bcr interacts with glutathione-s-transferase
# interleukin-4 interacts with transforming growth factor-beta
# ltk interacts with il-2
# tgf-beta interacts with tgf-beta 3
# cd30 interacts with cd7
# vdd1 interacts with ela1
# d-ala-d interacts with ferrochelatase
# il-6 interacts with interferon-gamma
# il-2r interacts with igg2b
# cd71 interacts with cd7
# splotch interacts with pax
# gelsolin interacts with abo
# glucose-6-phosphatase interacts with pyruvate carboxylase
# cd19 interacts with cd25
# il-2 interacts with il-1 beta
# adh5 interacts with adh3
# il-6 interacts with ifn-y
# grp interacts with avp
# n-cadherin interacts with bcr
# hla interacts with dr1
# hla interacts with drb1
# il-1 interacts with tnf alpha
# ass interacts with abo blood group
# interleukin-6 interacts with icam-1
# dr3 interacts with histocompatibility leucocyte antigens (hla)-b
# microsomal triglyceride transfer protein interacts with mtp
# il-4 interacts with gm-csf
# abl1 interacts with dbh
# il-4 interacts with interleukin (il) 1 alpha
# at iii interacts with afp
# tnf-alpha interacts with cd8
# insulin-like growth factor i interacts with rbp-1
# cd21 interacts with cd5
# interleukin-4 interacts with il-4
# bombesin interacts with neurotensin
# cd4 interacts with tnf
# galactokinase interacts with gal-1-put
# her-2/neu interacts with c-fms
# il-1 beta interacts with tumor necrosis factor-alpha
# hla-drb1 interacts with hla-dpb1
# cholecystokinin interacts with neurotensin
# estrogen receptor interacts with igf-i
# igf-ii interacts with igfbps
# hla-drb1 interacts with b18
# antithrombin iii interacts with c-reactive protein
# adh1 interacts with fdh
# gastrin-releasing peptide interacts with avp
# interleukin-1 alpha interacts with interleukin-6
# neural cell adhesion molecule interacts with ncam
# cd4 interacts with ril-1 beta
# p53 interacts with ki-ras
# insulin interacts with insulin-like growth factor i
# il-6 interacts with alpha 1-antitrypsin
# tumor necrosis factor interacts with il-3
# tnf interacts with tnf alpha

# %%
# key functionalities of the PubTator pipeline version 2:

# ## PubTator Pipeline V2

# ### Data Loading
# - Loads Gene-Disease dataset from Figshare and combines test/train files
# - Reads data into pandas DataFrame

# ### PubTator API
# - Queries PubTator API to fetch gene annotations for PMIDs
# - API accepts list of PMIDs and concepts like "gene"  
# - Makes requests in loop for each PMID
# - Parses XML response to extract gene info

# Key highlights are:

# - Loading and combining external dataset
# - Interacting with PubTator API to annotate entities
# - Storing annotations in a DataFrame structure
# - Analyzing annotations to find interactions 
# - Outputting results to file
# - Includes improvements like progress tracking, error handling etc.

########################
#  Change log after V1 to V2
#######################


# ### Data Storage
# - Stores gene annotations in a DataFrame
# - Contains columns for gene ID, name, PMID, type
# - Handles multiple annotations per PMID

# ### Post-Processing
# - Finds gene-gene interactions by mapping PMIDs to concepts
# - Outputs interactions to a text file

# ### Visualisation
# - Exploring sutable tools to visualise large network maps (underway...)

# ### Enhancements
# - Added progress bar to track API requests
# - Handles API errors and failures
# - Improved data structures for faster lookups
# - Added file output for analysis

# %%
# # Cytoscape!!

# import requests

# # Create a list of edges in Cytoscape JSON format
# edges = [{'data': {'source': source, 'target': target}} for source, target in gene_interaction]

# # Define the Cytoscape REST API URL
# cytoscape_url = 'http://localhost:1234/v1/'

# # Clear the current network in Cytoscape
# requests.delete(cytoscape_url + 'session')

# # Create a new network in Cytoscape
# requests.post(cytoscape_url + 'networks', json=edges)

# # Layout the network (optional)
# requests.post(cytoscape_url + 'apply/layouts/force-directed')

# # Open Cytoscape to view the network

# print("Open Cytoscape to view the network.")

# %%
gene_interaction_list = list(gene_interactions)

# Select the first 100 elements
first_200_elements = gene_interaction_list[:200]

# If you want to convert it back to a set (optional)
subset_associations = set(first_200_elements)

# %%
import networkx as nx
import plotly.graph_objects as go

# Create a graph
G = nx.Graph()

# Add nodes and edges to the graph
for interaction in subset_associations:
    source, target = interaction
    G.add_node(source)
    G.add_node(target)
    G.add_edge(source, target)

# Create positions for the nodes using a spring layout (you may need to try different layouts)
pos = nx.spring_layout(G)

# Create edge traces
edge_trace = go.Scatter(
    x=[],
    y=[],
    line=dict(width=0.5, color='#888'),
    hoverinfo='none',
    mode='lines')

for edge in G.edges():
    x0, y0 = pos[edge[0]]
    x1, y1 = pos[edge[1]]
    edge_trace['x'] += tuple([x0, x1, None])
    edge_trace['y'] += tuple([y0, y1, None])

# Create node traces
node_trace = go.Scatter(
    x=[],
    y=[],
    text=[],
    mode='markers',
    hoverinfo='text',  # Set hoverinfo to 'text' to display node names on hover
    marker=dict(
        showscale=True,
        colorscale='YlGnBu',
        size=10,
        colorbar=dict(
            thickness=15,
            title='Node Connections',
            xanchor='left',
            titleside='right'
        ),
        line=dict(width=2)))

for node in G.nodes():
    x, y = pos[node]
    node_trace['x'] += tuple([x])
    node_trace['y'] += tuple([y])
    node_trace['text'] += tuple([node])  # Store the node names for hover display

# Create a figure
fig = go.Figure(data=[edge_trace, node_trace],
                layout=go.Layout(
                    showlegend=False,
                    hovermode='closest',
                    margin=dict(b=0, l=0, r=0, t=0)))

# Show the interactive plot
fig.show()
# Out:
# <div>                            <div id="ff393979-2eb1-4e28-b020-c0216325cb64" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ff393979-2eb1-4e28-b020-c0216325cb64")) {                    Plotly.newPlot(                        "ff393979-2eb1-4e28-b020-c0216325cb64",                        [{"hoverinfo":"none","line":{"color":"#888","width":0.5},"mode":"lines","x":[-0.8349331622512095,-0.8281023520530233,null,-0.8349331622512095,-0.7981583421512938,null,-0.8349331622512095,-0.8944812031194392,null,-0.0839898189553116,-0.11158062521456719,null,-0.0839898189553116,-0.11241999097297566,null,-0.0839898189553116,-0.03152452306309634,null,-0.0839898189553116,-0.024438674661571805,null,-0.0839898189553116,-0.14303403175015472,null,-0.14303403175015472,-0.23778660941754867,null,-0.14303403175015472,-0.09199671779563041,null,-0.23778660941754867,-0.3190449738728252,null,-0.23778660941754867,-0.2910861032537996,null,0.789211941463598,0.8324257195165603,null,0.789211941463598,0.7431033342154006,null,-0.026333774645160624,-0.06808454926258443,null,-0.026333774645160624,0.07574915926850709,null,-0.026333774645160624,-0.0645169576417022,null,-0.026333774645160624,-0.09199671779563041,null,-0.4395144014483299,-0.47471605958228646,null,-0.4395144014483299,-0.4476720831137923,null,-0.4395144014483299,-0.4800315320438684,null,-0.4395144014483299,-0.4021263448815434,null,-0.47471605958228646,-0.4800315320438684,null,-0.11241999097297566,-0.1241232766687639,null,-0.11241999097297566,-0.14164953382238235,null,-0.1241232766687639,-0.13432673564222464,null,0.9002387637373793,0.9264975812694202,null,0.08853317202107369,0.057711196773868385,null,0.057711196773868385,0.05321554499047932,null,0.057711196773868385,0.06950470989723885,null,0.057711196773868385,0.018438687391918073,null,0.07574915926850709,0.10047794994920604,null,0.07574915926850709,0.06739800601567073,null,0.07574915926850709,0.093957791481743,null,0.07574915926850709,0.02825160866113691,null,0.07574915926850709,0.17293665245665338,null,0.07574915926850709,0.15475273861567757,null,0.07574915926850709,0.04401934659495006,null,-0.9268548790352947,-0.895315246954976,null,0.18750670104570147,0.21272585206921615,null,0.18750670104570147,0.16353590751890507,null,-0.3190449738728252,-0.3366965712752118,null,-0.3190449738728252,-0.34473489286131825,null,-0.3190449738728252,-0.36181654379544076,null,-0.3190449738728252,-0.3558703862972195,null,-0.3190449738728252,-0.35358455788644755,null,-0.12329394906769564,-0.12392745570443582,null,0.05091393587855084,0.093957791481743,null,0.05091393587855084,0.008137926749626824,null,0.05091393587855084,0.005007349592450492,null,0.05091393587855084,0.07453338441403388,null,0.093957791481743,0.09889345124687628,null,0.093957791481743,0.08736405886601291,null,0.093957791481743,0.15475273861567757,null,0.015376752558580337,0.04401934659495006,null,0.015376752558580337,-0.006324111049070753,null,-0.7664031499141444,-0.7325851863961088,null,-0.7325851863961088,-0.7105468840687545,null,0.27621787763295685,0.306594679042257,null,0.27621787763295685,0.30438292734991546,null,0.27621787763295685,0.2708990188174421,null,0.27621787763295685,0.3637750100720821,null,0.27621787763295685,0.33797364280742104,null,0.27621787763295685,0.2785577807464995,null,0.27621787763295685,0.17293665245665338,null,0.5051489042609257,0.544500010739325,null,0.5051489042609257,0.5507430736491661,null,0.5051489042609257,0.5330811433291694,null,0.5051489042609257,0.5200496157227902,null,0.5051489042609257,0.4174537705920003,null,0.5051489042609257,0.557608968567369,null,-0.344516828920702,-0.33560779832292986,null,-0.344516828920702,-0.3228734081739529,null,-0.33560779832292986,-0.3228734081739529,null,0.5507430736491661,0.5900194485894329,null,-0.80077032626 ...
